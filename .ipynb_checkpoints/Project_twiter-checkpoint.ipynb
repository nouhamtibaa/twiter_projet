# %% [markdown]
# # Projet: Fouille de données 1

# %% [markdown]
# ## Réaliser par: Nouha MTIBAA-3DNI_G1

# %% [markdown]
# ## Thème: Classification des Tweets

# %% [markdown]
# ## Objectifs:
# * Maitriser l’API de twitter pour l’extraction des tweets
# * Maitriser la partie NLP (naturallanguageprocessing) avec NLTK en Python
# * Appliquer les principes de nettoyage des données
# * Classer les tweets: regrouper ensemble les tweets qui sont similaires.C’est une étape qui peut être considérée comme une étape

# %% [markdown]
# ### Importation des bibliothéques nécessaires

# %%
import pandas as pd 
import tweepy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install tweepy
# !pip install pandas
# Out:
# Requirement already satisfied: tweepy in c:\users\nouha\anaconda\lib\site-packages (3.9.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\nouha\anaconda\lib\site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nouha\anaconda\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\nouha\anaconda\lib\site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nouha\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nouha\anaconda\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\nouha\anaconda\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nouha\anaconda\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\nouha\anaconda\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\nouha\anaconda\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.0)
# Requirement already satisfied: pandas in c:\users\nouha\anaconda\lib\site-packages (0.24.2)
# Requirement already satisfied: pytz>=2011k in c:\users\nouha\anaconda\lib\site-packages (from pandas) (2019.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\nouha\anaconda\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\nouha\anaconda\lib\site-packages (from pandas) (1.16.4)
# Requirement already satisfied: six>=1.5 in c:\users\nouha\anaconda\lib\site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)

# %% [markdown]
# ##### On doit récupérer les Tweets à partir de Twitter en utilisant l’API de twitter et les sauvgarder dans un fichier .csv

# %%
def scrape_function(words, date_since, numtweet): 
      
    # Creating DataFrame using pandas 
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following', 
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags']) 
      
    # We are using .Cursor() to search through twitter for the required tweets. 
    # The number of tweets can be restricted using .items(number of tweets) 
    tweets = tweepy.Cursor(api.search, q=words, lang="en", 
                           since=date_since, tweet_mode='extended').items(numtweet) 
     
    # .Cursor() returns an iterable object. Each item in  
    # the iterator has various attributes that you can access to  
    # get information about each tweet 
    list_tweets = [tweet for tweet in tweets] 
      
    # Counter to maintain Tweet Count 
    i = 1  
      
    # we will iterate over each tweet in the list for extracting information about each tweet 
    for tweet in list_tweets: 
        username = tweet.user.screen_name 
        description = tweet.user.description 
        location = tweet.user.location 
        following = tweet.user.friends_count 
        followers = tweet.user.followers_count 
        totaltweets = tweet.user.statuses_count 
        retweetcount = tweet.retweet_count 
        hashtags = tweet.entities['hashtags'] 
          
        # Retweets can be distinguished by a retweeted_status attribute, 
        # in case it is an invalid reference, except block will be executed 
        try: 
            text = tweet.retweeted_status.full_text 
        except AttributeError: 
            text = tweet.full_text 
        hashtext = list() 
        for j in range(0, len(hashtags)): 
            hashtext.append(hashtags[j]['text']) 
          
        # Here we are appending all the extracted information in the DataFrame 
        ith_tweet = [username, description, location, following, 
                     followers, totaltweets, retweetcount, text, hashtext] 
        db.loc[len(db)] = ith_tweet 
          
        # Function call to print tweet data on screen 
        printtweetdata(i, ith_tweet) 
        i = i+1
    filename = 'tweets.csv'
      
    # we will save our database as a CSV file. 
    db.to_csv(filename) 
  
  
if __name__ == '__main__': 
      
    # Enter your own credentials obtained  
    # from your developer account 
    consumer_key = "ry9GMoJRUCdsHo89bkpVosu8T"
    consumer_secret = "y9Yy5X6RE3n6hEogGhVYCmGDKgDPhWuQB8sexc61xKH01Xv6MA"
    access_key = "1330861473481052162-NXO8xkGNxf0g6A7wbOjOfMPKZrfUvT"
    access_secret = "20Ye373RjvjjMfpbPHAW6kbwJURRbqRaQsnMYFBCrZpyw"
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
    auth.set_access_token(access_key, access_secret) 
    api = tweepy.API(auth,wait_on_rate_limit=True) 
      
    # Enter Hashtag and initial date 
    print("Enter Twitter HashTag to search for") 
    words = input() 
    print("Enter Date since The Tweets are required in yyyy-mm--dd") 
    date_since = input() 
      
    # number of tweets you want to extract in one run 
    numtweet =2000
    scrape_function(words, date_since, numtweet) 
    print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# sport
# Enter Date since The Tweets are required in yyyy-mm--dd
# 10/10/2020
#
# Tweet 1:
# Username:YOYO_SYorks
# Description:YOYO Sport - You're Only Young Once
# Location:South Yorkshire
# Following Count:57
# Follower Count:328
# Total Tweets:1207
# Retweet Count:0
# Tweet Text:🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session before Christmas, so come down to Dorothy Hyman and take part in lots of festive multi-sport games!
#
# ⏰ 17:00 – 18:00 | Ages 8 – 13
# ⏰ 17:00 – 18:00 | Ages 14 – 16
#
# ⚠️ 𝘗𝘳𝘦-𝘣𝘰𝘰𝘬𝘪𝘯𝘨 𝘰𝘯𝘭𝘺 👉 https://t.co/Bzdp0QQico https://t.co/arR2YdB0Cd
# Hashtags Used:[]
#
# Tweet 2:
# Username:aatschilperoort
# Description:personal trainer strong selfdefence® 9th dan (upon request) | former💙captain | former dopingjudge | former emergency care assistant/ambu driver
# Location:Netherlands, Germany
# Following Count:368
# Follower Count:138
# Total Tweets:5362
# Retweet Count:3
# Tweet Text:As part of the new @wada_ama 2021 World Anti-Doping Code, a ban from sport can be extended by an additional two years in certain circumstances. 📢
#
# Make sure you’re aware of all the key changes in the new Code and read @ukantidoping’s summary guide
#
# 👉 https://t.co/wSvpBkyvBW https://t.co/6pEp72OB6Z
# Hashtags Used:[]
#
# Tweet 3:
# Username:NotFanucules
# Description:unapologetically white
# Location:
# Following Count:60
# Follower Count:37
# Total Tweets:1067
# Retweet Count:0
# Tweet Text:@IIWolfe1 @Justin420451408 @GBlattenberger @ormelling1 @BGOnTheScene Conservative far right militia group that stand with Marxists and BLM, by their own admission.
#
# "BuT fOrBeS sAiD!!1"
#
# You're batting 1.000, sport!
#
# https://t.co/2YmlLIpKp8 https://t.co/LboY3XsojR
# Hashtags Used:[]
#
# Tweet 4:
# Username:FrontPubHealth
# Description:The official Twitter Feed for all the latest open-access peer-reviewed articles in Frontiers in Public Health.
# Location:Lausanne, Switzerland
# Following Count:2381
# Follower Count:3737
# Total Tweets:3466
# Retweet Count:0
# Tweet Text:New Research: Cardiorespiratory Fitness Is Associated With Drop Out From Sport in Norwegian Adolescents. A Longitudinal Study: Several studies indicate that participation in organized sport may result in higher physical… https://t.co/U6USIRGzHU #PublicHealth #HealthForAll
# Hashtags Used:['PublicHealth', 'HealthForAll']
#
# Tweet 5:
# Username:ukantidoping
# Description:UKAD is the National Anti-Doping Organisation for the UK, protecting the right to enjoy doping-free sport.
# #CleanSport #ProtectYourSport
# Location:London
# Following Count:528
# Follower Count:17605
# Total Tweets:8178
# Retweet Count:3
# Tweet Text:As part of the new @wada_ama 2021 World Anti-Doping Code, a ban from sport can be extended by an additional two years in certain circumstances. 📢
#
# Make sure you’re aware of all the key changes in the new Code and read @ukantidoping’s summary guide
#
# 👉 https://t.co/wSvpBkyvBW https://t.co/6pEp72OB6Z
# Hashtags Used:[]
#
# Tweet 6:
# Username:englishlifting
# Description:Supporting the England Weightlifting Team; Olympic Weightlifters and IPC Powerlifters, since 2013. Onwards to Birmingham !
# Location:England
# Following Count:212
# Follower Count:1913
# Total Tweets:3525
# Retweet Count:3
# Tweet Text:As part of the new @wada_ama 2021 World Anti-Doping Code, a ban from sport can be extended by an additional two years in certain circumstances. 📢
#
# Make sure you’re aware of all the key changes in the new Code and read @ukantidoping’s summary guide
#
# 👉 https://t.co/wSvpBkyvBW https://t.co/6pEp72OB6Z
# Hashtags Used:[]
#
# Tweet 7:
# Username:DavidjhWelch
# Description:
# Location:
# Following Count:103
# Follower Count:233
# Total Tweets:41761
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 8:
# Username:GBWeightLifting
# Description:British Weight Lifting is the National Governing Body for Weightlifting & Para-Powerlifting in the UK
# Location:Leeds
# Following Count:1049
# Follower Count:13731
# Total Tweets:10169
# Retweet Count:3
# Tweet Text:As part of the new @wada_ama 2021 World Anti-Doping Code, a ban from sport can be extended by an additional two years in certain circumstances. 📢
#
# Make sure you’re aware of all the key changes in the new Code and read @ukantidoping’s summary guide
#
# 👉 https://t.co/wSvpBkyvBW https://t.co/6pEp72OB6Z
# Hashtags Used:[]
#
# Tweet 9:
# Username:anupsoans
# Description:MedicinMan @ https://t.co/23c4jdZV2e
# Location:Bangalore
# Following Count:2420
# Follower Count:7293
# Total Tweets:26881
# Retweet Count:0
# Tweet Text:@drnngujarathi @IamShajanSamuel @SandeepMall You're like the Iceman - Bjorn Borg
#
# The greatest: Bjorn Borg – enigma with a bomb-proof winning mentality | Tim Lewis https://t.co/VkkrVNS8hb https://t.co/QpgJHCHKbG
# Hashtags Used:[]
#
# Tweet 10:
# Username:NonLeagueCrowd
# Description:Love Non League Football and the fact that thousands of people watch this day after day after day. Pic - Hemel Hempstead vs Chesham
# Location:
# Following Count:3758
# Follower Count:33493
# Total Tweets:367940
# Retweet Count:3
# Tweet Text:@RocesterFC1876 @FA @MidlandLeague @CommonsDCMS The FA &amp; DCMS have recently clarified that non-league clubs can have fans in tier 3 areas.
#
# It looks like they've misinterpreted the guidance that's meant for elite sport.
#
# https://t.co/ZGN3ytsc5Q
# Hashtags Used:[]
#
# Tweet 11:
# Username:nitsujO
# Description:
# Location:
# Following Count:16
# Follower Count:3
# Total Tweets:251
# Retweet Count:0
# Tweet Text:December 16, 2020 10:14 PM
#
# DUBAI (Reuters) - Doha beat Riyadh to clinch the hosting rights for the 2030 Asian Games at the general assembly of the Olympic Council of Asia on Wednesday in Muscat, the regional governing body announced.https://t.co/ZbAKeTSsry
# Hashtags Used:[]
#
# Tweet 12:
# Username:fozzer2006
# Description:Proud Unionist - Supporter of our Armed Forces - Love Northern Soul & Motown music - Keep The Faith  Parler @fozzer2006
# Location:
# Following Count:964
# Follower Count:3305
# Total Tweets:39707
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 13:
# Username:NJdelerium
# Description:Life/Football/More Life/More Football
# Location:
# Following Count:1196
# Follower Count:166
# Total Tweets:4793
# Retweet Count:3
# Tweet Text:@RocesterFC1876 @FA @MidlandLeague @CommonsDCMS The FA &amp; DCMS have recently clarified that non-league clubs can have fans in tier 3 areas.
#
# It looks like they've misinterpreted the guidance that's meant for elite sport.
#
# https://t.co/ZGN3ytsc5Q
# Hashtags Used:[]
#
# Tweet 14:
# Username:ProperDemocrat
# Description:People can only live properly if they take (sensible) risks. Stop postal votes abuses.@Anti-democratic bots blocked.
# Location:The real world
# Following Count:944
# Follower Count:1671
# Total Tweets:75720
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 15:
# Username:GillJames54
# Description:Love my country 🏴󠁧󠁢󠁥󠁮󠁧󠁿🇬🇧 It has been messed up by bloody politicians ! Love family, Mum of 3 Nan to 9 .Love flowers and animals too .No DMs please 😊
# Location:England, United Kingdom
# Following Count:5583
# Follower Count:5538
# Total Tweets:220761
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 16:
# Username:Daniel_Boullosa
# Description:In veritas libertas
# Location:BSB-VIG
# Following Count:827
# Follower Count:1146
# Total Tweets:3800
# Retweet Count:0
# Tweet Text:#Childhood &amp; #adolescent coach-led multi-sport practice was a critical #discriminator of #adult practice efficiency and #performance improvement. Associations were non-linear, displaying a saturation pattern.
#
# https://t.co/Lk4jHJxn0c
# Hashtags Used:['Childhood', 'adolescent', 'discriminator', 'adult', 'performance']
#
# Tweet 17:
# Username:Ollie_Bayliss
# Description:Journalist, Football Commentator & Presenter of The Non-League Show on BBC Three Counties Radio. Researcher for @FootballManager. *views are mine not the BBC's
# Location:
# Following Count:5363
# Follower Count:36045
# Total Tweets:10009
# Retweet Count:3
# Tweet Text:@RocesterFC1876 @FA @MidlandLeague @CommonsDCMS The FA &amp; DCMS have recently clarified that non-league clubs can have fans in tier 3 areas.
#
# It looks like they've misinterpreted the guidance that's meant for elite sport.
#
# https://t.co/ZGN3ytsc5Q
# Hashtags Used:[]
#
# Tweet 18:
# Username:Dish_Sport_Live
# Description:DISH KI DUNYA ME NUMBER ONE ID NEW CHANNELS NEW ALL KEYS ALL SPORTS UPDATES OR SUB KUCH AP KY LIYE
# FOLLOW @Dish_Sport_Live
# Send To 40404
# Location:KPK Lakki,Marwat Pakistan
# Following Count:50
# Follower Count:4475
# Total Tweets:40479
# Retweet Count:0
# Tweet Text:KFC Big Bash League 2020/21
# Today Match Abonded Due To Rain.
#
# SCORES: https://t.co/X1NGOBwTkv #BBL10 https://t.co/HGmFg7F3pE
# +
# Follow @Dish_Sport_Live
# Hashtags Used:['BBL10']
#
# Tweet 19:
# Username:MarieCotte3
# Description:TSS - TCAE
# Location:Santander, España
# Following Count:35
# Follower Count:39
# Total Tweets:721
# Retweet Count:56
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/LRyM2xOsGr https://t.co/mg8GgoPURM
# Hashtags Used:[]
#
# Tweet 20:
# Username:FrontSportsAL
# Description:Official Twitter feed for the latest #openaccess peer-reviewed research in @Frontiersin Sports & Active Living.
# Location:United Kingdom
# Following Count:1859
# Follower Count:2454
# Total Tweets:694
# Retweet Count:0
# Tweet Text:An Interdisciplinary Examination of #Stress and #Injury Occurrence in #Athletes 🧘
#
# Read the full #OpenAccess paper by @harryfishr et al. here: https://t.co/1qoQzZUFWx #sport https://t.co/5Ll6FNJy1e
# Hashtags Used:['Stress', 'Injury', 'Athletes', 'OpenAccess', 'sport']
#
# Tweet 21:
# Username:Isabell56416820
# Description:
# Location:
# Following Count:455
# Follower Count:874
# Total Tweets:57635
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 22:
# Username:rockapepolitics
# Description:love politics. from Liverpool but in a brexit town. love political satire. brexiter.  firm belief in freedom of speech. anti woke. patriot.
# Location:U.K. Weaver Vale
# Following Count:1256
# Follower Count:1472
# Total Tweets:157816
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 23:
# Username:ShropshireStar
# Description:Breaking news and sport from the Shropshire Star | Email us at newsroom@shropshirestar.co.uk.
# Location:Shropshire, UK
# Following Count:3053
# Follower Count:89957
# Total Tweets:117086
# Retweet Count:0
# Tweet Text:ICYMI: AFC Telford netted 10 against Coleshill #Bucks
#
# https://t.co/fOlNQgdfnz
# Hashtags Used:['Bucks']
#
# Tweet 24:
# Username:bfccommunity
# Description:We are a registered charity that uses the power of football and @BarnsleyFC to engage and improve the lives of local people.
# Location:Barnsley, England
# Following Count:553
# Follower Count:3193
# Total Tweets:8306
# Retweet Count:0
# Tweet Text:🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session before Christmas, so come down to Dorothy Hyman and take part in lots of festive multi-sport games!
#
# ⏰ 17:00 – 18:00 | Ages 8 – 13
# ⏰ 17:00 – 18:00 | Ages 14 – 16
#
# ⚠️ 𝘗𝘳𝘦-𝘣𝘰𝘰𝘬𝘪𝘯𝘨 𝘰𝘯𝘭𝘺 👉 https://t.co/Bzdp0QQico https://t.co/arR2YdB0Cd
# Hashtags Used:[]
#
# Tweet 25:
# Username:RodrigoZacca
# Description:🎓 BSc @unisinos🇧🇷
# 🎓 MSc @ufrgsnoticias 🇧🇷
# 🎓 Ph.D #SportScience @uporto 🇵🇹
# 👨🏻‍🔬 Researcher @labiomep 🇵🇹
# Location:
# Following Count:4752
# Follower Count:1521
# Total Tweets:13260
# Retweet Count:16
# Tweet Text:New @IJSPPjournal Editorial with @davidtmartin ‘Factories, Movies and Sport Science’.. exploring inspiration, creativity and impact in high performance sport and academia https://t.co/fdr0AMBAwu
# Hashtags Used:[]
#
# Tweet 26:
# Username:pambrose33
# Description:We've left the EU, guys. Get over it.
# Location:Manchester, England
# Following Count:160
# Follower Count:151
# Total Tweets:23320
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 27:
# Username:FallonRogeri
# Description:Europhile and rational optimist. Chooses democracy over European Commission. Dyed in the wool Red (LFC). Follow Rangers. #Standup4Brexit
# Location:United Kingdom
# Following Count:159
# Follower Count:366
# Total Tweets:41228
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 28:
# Username:KarlMGriffiths
# Description:
# Location:
# Following Count:70
# Follower Count:145
# Total Tweets:88309
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 29:
# Username:Godfrey28482926
# Description:Retired IT Project Manager
# Conservative Party member.
# Proud 'Boomer' -  We created the modern, civilised, prosperous, secular, technological world.
# Location:South East England.
# Following Count:532
# Follower Count:834
# Total Tweets:99562
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 30:
# Username:oflynnsocial
# Description:Freeing the UK of rule by the BOOGIB (Bunch Of Old Guys In Belgium). SDP Brexit spokesman. Political commentator.
# Location:
# Following Count:4938
# Follower Count:59868
# Total Tweets:103985
# Retweet Count:14
# Tweet Text:Here's one  recent poll showing how football is replacing a unifying approach to tackling racism with one that is highly divisive https://t.co/gCL14z1qMl
# Hashtags Used:[]
#
# Tweet 31:
# Username:turnarounduk
# Description:Book distributors for US & UK indie publishers including fiction, art, graphic novels, and everything in-between!
# Location:London
# Following Count:3200
# Follower Count:5062
# Total Tweets:21573
# Retweet Count:0
# Tweet Text:@septemberbooks @herb_lester @Liminal_11 Still looking for that last minute gift? Our sport book selection has something for fans of all shirts and stripes.
#
# With bestsellers from @penguinpress, @SportsVsp and more.
#
# Browse the full gift guide: https://t.co/PN2hUZJfDf https://t.co/oa7nI5x5na
# Hashtags Used:[]
#
# Tweet 32:
# Username:MichaelPhelps36
# Description:Tweeting about top fantasy Michael Phelps stories
# Location:Coventry
# Following Count:725
# Follower Count:710
# Total Tweets:8857
# Retweet Count:0
# Tweet Text:Asked how clean he thinks the Olympics will be next year, Michael Phelps says 'four or five' out of 10 - CNN International https://t.co/reK6lWaDg5
# Hashtags Used:[]
#
# Tweet 33:
# Username:IrishSunSport
# Description:The latest on GAA, League of Ireland, Premier League & Champions League.  https://t.co/8lZBrw0kwQ and https://t.co/SU5YsGVLgg
# Location:Dublin
# Following Count:2130
# Follower Count:8033
# Total Tweets:122376
# Retweet Count:0
# Tweet Text:Best Fifa nominee Ronaldo not even in top 10 players of 2020, with Messi No1 https://t.co/b0D0A5xCAb
# Hashtags Used:[]
#
# Tweet 34:
# Username:GPFansGlobal
# Description:All the latest news, views and action from Formula One, focusing on the drivers and what makes them great!
# Location:The Grid
# Following Count:546
# Follower Count:1220
# Total Tweets:7174
# Retweet Count:0
# Tweet Text:It was an #F1 season no-one thought possible nine, 10 months ago, so no wonder Ross Brawn feels to proud of what the sport has achieved -
# https://t.co/9QTNXWwqZT
# Hashtags Used:['F1']
#
# Tweet 35:
# Username:ElectroTim
# Description:Professor of Physiotherapy, University of Hertfordshire. Interest in Electrotherapy, Electro Physical Agents and Tissue Repair. Post a review + orig paper daily
# Location:UK
# Following Count:94
# Follower Count:6163
# Total Tweets:2858
# Retweet Count:0
# Tweet Text:Sys Rev  + Meta: Pain control after shoulder arthroscopy. 83 RCTs - which is good - but nearly all pharma based. Cryo and TENS get a brief mention: Hurley et al (2020) Am J Sport Med:0363546520971757 https://t.co/0nF46e9g1D
# Hashtags Used:[]
#
# Tweet 36:
# Username:BucksWriter
# Description:I'm Richard Worton, scratching a life-long itch writing for & about @telfordutd:
# Programme
# Twitter
# @ShropshireStar
# @NonLeaguePaper
# @NLFullTime podcast
# Location:Telford, England
# Following Count:1437
# Follower Count:958
# Total Tweets:18550
# Retweet Count:2
# Tweet Text:Quite a night in North Warwickshire for @telfordutd as they ran into double digits in the @BuildbaseUK #FATrophy, defeating @coleshilltownfc by a club record margin. Here's my report for the @ShropshireStar as the Bucks ran amok:  https://t.co/nEceVhgxwO
# Hashtags Used:['FATrophy']
#
# Tweet 37:
# Username:telfordutd
# Description:The Official Twitter feed of AFC Telford United Football Club, bringing you all the latest news from the New Bucks Head.
# Location:Telford, United Kingdom
# Following Count:211
# Follower Count:22850
# Total Tweets:70609
# Retweet Count:2
# Tweet Text:Quite a night in North Warwickshire for @telfordutd as they ran into double digits in the @BuildbaseUK #FATrophy, defeating @coleshilltownfc by a club record margin. Here's my report for the @ShropshireStar as the Bucks ran amok:  https://t.co/nEceVhgxwO
# Hashtags Used:['FATrophy']
#
# Tweet 38:
# Username:dylanhale66_16
# Description:St. Luke’s ‘21 LB/WR/ATH | 6'1, 180 | 6'3" wingspan | 10 3/8" handspan | 3.0 Core | 2021 O-D All American | 2020 FBU Top Gun | 4-Year Starter | 4-Sport Athlete
# Location:Mobile, AL
# Following Count:2202
# Follower Count:298
# Total Tweets:1015
# Retweet Count:0
# Tweet Text:@Coach_Windham Come back to 251 Coach!
# 2021 LB/Gunner in Mobile, AL
# 6’1”, 180
# Wingspan: 6’3”
# Handspan: 10 ⅜””
# 2021 Offense-Defense All American
# 2020 FBU Top Gun
# 4-Year starter
# 4-Sport athlete
# Core GPA: 3.0
# https://t.co/UctKZdFSIU
# Hashtags Used:[]
#
# Tweet 39:
# Username:Marketing101__
# Description:Learn How To Market Yourself Like A F*****g Boss.
# Location:
# Following Count:2
# Follower Count:145
# Total Tweets:4934
# Retweet Count:0
# Tweet Text:In a groundbreaking "armpit advertising" campaign revealed on Thursday, Cricket Australia announced a commercial partnership with the Australian deodorant and antiperspirant brand Rexona. https://t.co/zo4TKMVGeO
# Hashtags Used:[]
#
# Tweet 40:
# Username:dylanhale66_16
# Description:St. Luke’s ‘21 LB/WR/ATH | 6'1, 180 | 6'3" wingspan | 10 3/8" handspan | 3.0 Core | 2021 O-D All American | 2020 FBU Top Gun | 4-Year Starter | 4-Sport Athlete
# Location:Mobile, AL
# Following Count:2202
# Follower Count:298
# Total Tweets:1015
# Retweet Count:0
# Tweet Text:@West4theWin Dylan Hale
# 2021 LB/WR/ATH in Mobile, AL
# 6’1”, 180
# Wingspan: 6’3”
# Handspan: 10 ⅜””
# 2021 Offense-Defense All American
# 2020 FBU Top Gun
# 4-Year starter
# 4-Sport athlete
# Core GPA: 3.0
# https://t.co/UctKZdFSIU
# Hashtags Used:[]
#
# Tweet 41:
# Username:maaisywills
# Description:there is beauty in simplicity
# Location:
# Following Count:254
# Follower Count:571
# Total Tweets:17091
# Retweet Count:25
# Tweet Text:A pressure group, aiming to hold the sport of gymnastics to account in the wake of a shocking abuse scandal revealed by ITV News, has been launched, writes @stevescott_itv
#
# https://t.co/TbGJ9UeMeA
# Hashtags Used:[]
#
# Tweet 42:
# Username:Mat_Germain_
# Description:Support good people & ideas.
# Health Care should be well funded & non-profit.
# Condolences to those who lost loved ones to COVID19.
# Location:Earth, Orion arm, Milky Way
# Following Count:1141
# Follower Count:1011
# Total Tweets:35821
# Retweet Count:0
# Tweet Text:@TSN_Sports Example:
# Lionel Andres Messi is the highest-paid soccer player in the world, earning $126 million in 2020. He plays 10 yrs, he's got over $1.3B (+ interest) &amp; can buy himself a franchise in any other sport.
# Hashtags Used:[]
#
# Tweet 43:
# Username:ExtraSideOfKyle
# Description:
# Location:New York, NY
# Following Count:59
# Follower Count:63
# Total Tweets:349
# Retweet Count:0
# Tweet Text:Hey @MLB interested to know more about the 'unification' of the sport of baseball (from youth league all way up) via MLB ONE BASEBALL initiative.I’m confused why something so big (&amp; already under way) isn’t being promoted or explained in detail to anyone?? https://t.co/4SY99zZiPS
# Hashtags Used:[]
#
# Tweet 44:
# Username:parentsvip
# Description:I'm just a father who cares. That's why I bought and recommend mSpy ↓↓↓
# Location:
# Following Count:2490
# Follower Count:367
# Total Tweets:1842
# Retweet Count:0
# Tweet Text:https://t.co/CWUd5XlpJW
# The water is the perfect temperature as it is cooler than during the day. Numerous tackles offered are devices, belts, lines, baits and lures. Missing it by a day or 2 is all that it requires to loose out on
# Hashtags Used:[]
#
# Tweet 45:
# Username:DesBoss
# Description:I'm a Non-Executive Director of a Social Housing Landlord. I operate https://t.co/mFgWJBDS5R. DogSiteWorld Writer Offering Free Unique Content Rich Dog Articles
# Location:United Kingdom
# Following Count:3578
# Follower Count:3373
# Total Tweets:67350
# Retweet Count:0
# Tweet Text:The sport of surfing originated in Hawaii @OMGFacts @UberFacts @WhatTheFFacts #dogs
# Wed Dec 16 2020 00:10:41 GMT+0000 (UTC)
# Hashtags Used:['dogs']
#
# Tweet 46:
# Username:BucksWriter
# Description:I'm Richard Worton, scratching a life-long itch writing for & about @telfordutd:
# Programme
# Twitter
# @ShropshireStar
# @NonLeaguePaper
# @NLFullTime podcast
# Location:Telford, England
# Following Count:1437
# Follower Count:958
# Total Tweets:18550
# Retweet Count:2
# Tweet Text:Quite a night in North Warwickshire for @telfordutd as they ran into double digits in the @BuildbaseUK #FATrophy, defeating @coleshilltownfc by a club record margin. Here's my report for the @ShropshireStar as the Bucks ran amok:  https://t.co/nEceVhgxwO
# Hashtags Used:['FATrophy']
#
# Tweet 47:
# Username:RTEsoccer
# Description:Irish and International soccer news from RTÉ | @soccrepublic #RTEsoccer
# Location:Ireland
# Following Count:199
# Follower Count:65650
# Total Tweets:75026
# Retweet Count:0
# Tweet Text:Fourth win on the spin for Real https://t.co/hZ5vBryNYJ #rtesoccer
# Hashtags Used:['rtesoccer']
#
# Tweet 48:
# Username:TheAvenueHotel2
# Description:Do law of attraction allows you to manifest and bring more into your life!
# Location:
# Following Count:1104
# Follower Count:416
# Total Tweets:2484
# Retweet Count:0
# Tweet Text:https://t.co/D5uQRVPvYW
# Searching for something a little bit more daring in your Texas saltwater fishing trip? Placing the carriage ends up being a huge problem. Some spe
# Hashtags Used:[]
#
# Tweet 49:
# Username:ShropshireStar
# Description:Breaking news and sport from the Shropshire Star | Email us at newsroom@shropshirestar.co.uk.
# Location:Shropshire, UK
# Following Count:3053
# Follower Count:89957
# Total Tweets:117086
# Retweet Count:0
# Tweet Text:What a result for AFC Telford!
#
# They netted 10 (ten!) against Coleshill Town in the FA Trophy this evening #Bucks
#
# https://t.co/fOlNQgdfnz
# Hashtags Used:['Bucks']
#
# Tweet 50:
# Username:staronline
# Description:News updates from Malaysia's top English-language daily and website
# Location:Kuala Lumpur, Malaysia
# Following Count:213
# Follower Count:1649822
# Total Tweets:385398
# Retweet Count:0
# Tweet Text:Benzema double sees off 10-man Athletic as Real win again
# https://t.co/JUUJFrO6Za  https://t.co/JUUJFrO6Za
# Hashtags Used:[]
#
# Tweet 51:
# Username:Rocketman_Jon
# Description:"The sky is part of creation in which nature has done for the sake of pleasing man." 🚀 (JRT) 🚀
# Location:Gloucester, UK.
# Following Count:2440
# Follower Count:1249
# Total Tweets:89738
# Retweet Count:1
# Tweet Text:Best Fifa nominee Ronaldo not even in top 10 players of 2020, with Messi No1 https://t.co/O8LfaxDInv
# Hashtags Used:[]
#
# Tweet 52:
# Username:SunSport
# Description:Exclusive stories and breaking news from @TheSun's sport desk.
# Location:London
# Following Count:352
# Follower Count:192592
# Total Tweets:168321
# Retweet Count:1
# Tweet Text:Best Fifa nominee Ronaldo not even in top 10 players of 2020, with Messi No1 https://t.co/O8LfaxDInv
# Hashtags Used:[]
# Tweet 53:
# Username:JosepCampos_PhD
# Description:Josep Campos, PhD. | Sports - Tennis - Teaching - Higher Education - Coaches Education - Physical Education - Science - Research - Consultant
# Location:Catalunya
# Following Count:4997
# Follower Count:1933
# Total Tweets:9425
# Retweet Count:0
# Tweet Text:“Non-linear association of efficiency of practice of adult elite athletes with their youth multi-sport practice” by Michael Barth
#
# #multisport
# #LTAD
# #Sports https://t.co/9iKBJrLa0y
# Hashtags Used:['multisport', 'LTAD', 'Sports']
#
# Tweet 54:
# Username:davidapoms
# Description:Father, grandfather, entrepreneur, founder and CEO of Poms & Associates, Trustee of the U.S. Olympic & Paralympic Foundation, community advocate, sports fan
# Location:Woodland Hills, Calif.
# Following Count:71
# Follower Count:18
# Total Tweets:484
# Retweet Count:0
# Tweet Text:The US Olympic Committee announced athletes will not be disciplined for protesting during the upcoming games in Tokyo. https://t.co/QhQA9dzQnN
# Hashtags Used:[]
#
# Tweet 55:
# Username:standardsport
# Description:Latest sports news, views and live football from the @EveningStandard.
# Location:London, England
# Following Count:828
# Follower Count:41669
# Total Tweets:177220
# Retweet Count:0
# Tweet Text:10 minutes left in an entertaining second half at Molineux.
#
# Can either of these sides find a late winner?
#
# #WOLCHE
#
# https://t.co/OsoN3MjYFc
# Hashtags Used:['WOLCHE']
#
# Tweet 56:
# Username:Astronaut84
# Description:1% chance 99% faith 🛐
# Location:Jupiter 🪐
# Following Count:1785
# Follower Count:2001
# Total Tweets:1925
# Retweet Count:1
# Tweet Text:Cristiano Ronaldo not even in top 10 players of 2020 according to data, with Messi above Lewandowski https://t.co/8uZ8eVpXLm
# Hashtags Used:[]
#
# Tweet 57:
# Username:AbdullahALAsmi5
# Description:
# Location:Muscat, Oman
# Following Count:128
# Follower Count:125
# Total Tweets:1596
# Retweet Count:0
# Tweet Text:Best Fifa nominee Ronaldo not even in top 10 players of 2020, with Messi No1 https://t.co/npAlxZna8Y
# What I don’t really understand is why is  Benzema at 8th place?!
# Oh I know why, because he plays for Real Madrid🤣
# Hashtags Used:[]
#
# Tweet 58:
# Username:rheasilvia14
# Description:I believe in free speech, biology and data.
# Location:
# Following Count:50
# Follower Count:9
# Total Tweets:21
# Retweet Count:385
# Tweet Text:I am delighted to announce that Hilton and Lundberg, 2020 is now published! @TLexercise
#
# ‘Transgender Women in the Female Category of Sport: Perspectives on Testosterone Suppression and Performance Advantage’
#
# https://t.co/GseD8W2rUp https://t.co/eJebU3rDhR
# Hashtags Used:[]
#
# Tweet 59:
# Username:spaintodaynews
# Description:
# Location:
# Following Count:29
# Follower Count:4
# Total Tweets:102
# Retweet Count:0
# Tweet Text:Health reports 10,328 new cases and 388 more deaths, while the incidence rises to 198 - https://t.co/viOKozRT4W - Spain Today - Breaking News, Latest Sport, Current Information for Spain https://t.co/rf0KoaVpRQ
# Hashtags Used:[]
#
# Tweet 60:
# Username:TheSunFootball
# Description:Breaking news, goals, live coverage and more. Give us a like on Facebook too: https://t.co/JcmSsjtOAm
# Location:
# Following Count:602
# Follower Count:477219
# Total Tweets:262367
# Retweet Count:1
# Tweet Text:Cristiano Ronaldo not even in top 10 players of 2020 according to data, with Messi above Lewandowski https://t.co/8uZ8eVpXLm
# Hashtags Used:[]
#
# Tweet 61:
# Username:Sheikhjabaal
# Description:Cool Calm Collected and Composed
# Location:Lagos, Nigeria
# Following Count:1047
# Follower Count:8
# Total Tweets:217
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 62:
# Username:CorykSandC
# Description:Strength and Science, Chicago Cubs. Father of a frenchie and avid competitor. Views are my own. 🇨🇦
# Location:Mesa, AZ
# Following Count:1372
# Follower Count:1798
# Total Tweets:24855
# Retweet Count:2
# Tweet Text:⚠️Happy to share this opinion produced with @ajbeardo where we discuss past, actual and new issues faced by the practitioners and researchers that are at the front line of professional and elite sport...
# https://t.co/YPaY2wpT32
# Hashtags Used:[]
#
# Tweet 63:
# Username:SiphoNtobela5
# Description:Artisan.Believer In God.Patriotic Son Of The Soil.Music Stan
# Location:Umlazi, South Africa
# Following Count:5381
# Follower Count:5059
# Total Tweets:87147
# Retweet Count:12
# Tweet Text:PITSO STARTS 2020/2021 CAMPAIGN IN BLISTERING FASHION
#
# His record since joining Al Ahly
#
# Games: 11
# Wins: 10
# Draws: 1
# Goals scored/conceded: 25/7
# Trophies: 3
#
# https://t.co/BSlpvhbu0R
# Hashtags Used:[]
#
# Tweet 64:
# Username:JUST_JORDY
# Description:FS Wrestler #MMA #DimMak 💪🏻 #WrestlingIsLife Sports Medicine. USC Emerg. Med “Give it all you got” 🇺🇸 #BidenHarris2020 #ChampionVision
# Location:California via Georgia
# Following Count:214
# Follower Count:391
# Total Tweets:16448
# Retweet Count:1
# Tweet Text:FANTASTIC promotion for our sport as @DelbartonSports  and @BC_Crusaders announce they'll wrestle what is believed to be the first outdoor high school wrestling match in NJ on April 10
#
#  https://t.co/YMNokYbi5Z via @northjersey
#
# @bergenchswrstl
# Hashtags Used:[]
#
# Tweet 65:
# Username:ajbeardo
# Description:Director, High Performance - Chicago Cubs @Cubs
# Location:
# Following Count:3778
# Follower Count:5958
# Total Tweets:1596
# Retweet Count:2
# Tweet Text:⚠️Happy to share this opinion produced with @ajbeardo where we discuss past, actual and new issues faced by the practitioners and researchers that are at the front line of professional and elite sport...
# https://t.co/YPaY2wpT32
# Hashtags Used:[]
#
# Tweet 66:
# Username:sport_sinner
# Description:PLEASE FORGIVE US FOR WHAT YOU'RE ABOUT TO READ
# Location:Parts Unshaven
# Following Count:435
# Follower Count:275
# Total Tweets:574
# Retweet Count:0
# Tweet Text:@ForTheWin Why doesn't @Lane_Kiffin stop being coy and just admit he's next in line for the Alabama job?
# https://t.co/YSk9WDzJf4
# Hashtags Used:[]
#
# Tweet 67:
# Username:DannyRollinson1
# Description:Sports comms @VeroSport & @WSportsGroup
# Location:
# Following Count:599
# Follower Count:144
# Total Tweets:83
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 68:
# Username:TheBhupiThakur
# Description:Tweets regarding
# Nutrition Football Running
# In that order⚽🔥❤🤘💪
# Location:
# Following Count:1333
# Follower Count:76
# Total Tweets:2152
# Retweet Count:62
# Tweet Text:After countless conversations w/ @BARRYD22 &amp; multiple iterations, we're happy to see this published in @EurJSportSci...
#
# A Framework for Effective Knowledge Translation and Performance Delivery of Sport Scientists in Professional Sport
#
# https://t.co/K8o1ZQLgCA https://t.co/8rAixfWhV5
# Hashtags Used:[]
#
# Tweet 69:
# Username:BrocherieF
# Description:Exercise and environmental physiology, Strength and Conditioning & Sports Sciences Support.  Views are my own;-)
# Location:Paris, France
# Following Count:522
# Follower Count:894
# Total Tweets:1545
# Retweet Count:2
# Tweet Text:⚠️Happy to share this opinion produced with @ajbeardo where we discuss past, actual and new issues faced by the practitioners and researchers that are at the front line of professional and elite sport...
# https://t.co/YPaY2wpT32
# Hashtags Used:[]
#
# Tweet 70:
# Username:jake_bickerton
# Description:Editor of @Broadcast_Sport & @Broadcast_Tech & tech editor of @Broadcastnow. Also write about & make music. @Spotify artist account – https://t.co/b6DOr9O2Ey
# Location:London
# Following Count:672
# Follower Count:1541
# Total Tweets:3798
# Retweet Count:1
# Tweet Text:'@primevideouk has picked up the rights for the first midweek round of #PremierLeague fixtures this season. It's streaming 10 #live #matches this week, beginning tonight, with @Wolves v @ChelseaFC, which kicks off at 18:00. https://t.co/vYnS26J7t9
# Hashtags Used:['PremierLeague']
#
# Tweet 71:
# Username:broadcast_sport
# Description:The business of sports media. Daily #sports #production, #distribution and #tech #innovation news. Quarterly magazine, runs regular sports industry events.
# Location:London, England
# Following Count:590
# Follower Count:1585
# Total Tweets:1923
# Retweet Count:1
# Tweet Text:'@primevideouk has picked up the rights for the first midweek round of #PremierLeague fixtures this season. It's streaming 10 #live #matches this week, beginning tonight, with @Wolves v @ChelseaFC, which kicks off at 18:00. https://t.co/vYnS26J7t9
# Hashtags Used:['PremierLeague', 'live', 'matches']
#
# Tweet 72:
# Username:WADA_WTF
# Description:Reliable information on doping in world sport
# Location:
# Following Count:625
# Follower Count:555
# Total Tweets:704
# Retweet Count:0
# Tweet Text:Asked how clean he thinks the Olympics will be next year, Michael Phelps says 'four or five' out of 10
# https://t.co/73AHrrpmus
# #doping #sport #CleanSport
# Hashtags Used:['doping', 'sport', 'CleanSport']
#
# Tweet 73:
# Username:MarkHalliwell1
# Description:Dad of 3, Robin, Hornet, journalist, commentator, obsessed by stats, Diet Coke addict #BlackLivesMatter
# Location:Cheltenham, England
# Following Count:1281
# Follower Count:2953
# Total Tweets:142513
# Retweet Count:1
# Tweet Text:Well when one big name leaves the best way to soften the blow is announce the arrival of another
#
# Gloucester look short of options at 10 in the interim though just four games into the 2020/21 season
#
# https://t.co/riXVaH8Shw
# Hashtags Used:[]
# Tweet 74:
# Username:JohnEvely_BPost
# Description:South West Rugby Writer covering Bristol Bears, Bath Rugby, Gloucester Rugby and Exeter Chiefs. What a job I have!
# Jonathan.evely@reachplc.com / 07715770289
# Location:Bristol, England
# Following Count:3106
# Follower Count:3501
# Total Tweets:23855
# Retweet Count:1
# Tweet Text:Well when one big name leaves the best way to soften the blow is announce the arrival of another
#
# Gloucester look short of options at 10 in the interim though just four games into the 2020/21 season
#
# https://t.co/riXVaH8Shw
# Hashtags Used:[]
#
# Tweet 75:
# Username:luxurytravel
# Description:Editor of A Luxury Travel Blog: https://t.co/gKsDOz23mh
# Voted "one of the world's best travel blogs" by The Telegraph
# Contact us: https://t.co/ongkx7kwYF
# Location:
# Following Count:524011
# Follower Count:707069
# Total Tweets:257665
# Retweet Count:0
# Tweet Text:Top 10 luxury travel gifts for her this Christmas (US &amp; Canada edition) including the Lauren Sport from MotoChic Gear https://t.co/YeOvuZF3J3 https://t.co/8882nBzc1s
# Hashtags Used:[]
#
# Tweet 76:
# Username:briankrichter
# Description:Professor @UTexasMcCombs | Senior Stigler Fellow @StiglerCenter @ChicagoBooth | #PoliticalEconomy #NonMarketStrategy #BusinessAndPolitics #Lobbying #CSR #ESG
# Location:Austin, TX
# Following Count:3271
# Follower Count:490
# Total Tweets:267
# Retweet Count:0
# Tweet Text:@NateMJensen True, but does she know you can now go pro in tag?
#
# https://t.co/jkmtwbGS1q
# Hashtags Used:[]
#
# Tweet 77:
# Username:VeroSport
# Description:Strategic comms agency advising clients in the business of sport, including intl feds, bid & organising committees, brands, sponsors, rights holders & many more
# Location:London, UK
# Following Count:1142
# Follower Count:2708
# Total Tweets:4754
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 78:
# Username:MarcusChhan
# Description:Editor for @Dugout SE Asia. Former ESPN Star / FOX Sports Asia journo. #MUFC Fan.
# Location:Singapore - Brunei
# Following Count:560
# Follower Count:394
# Total Tweets:12154
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 79:
# Username:JigarVekariya9
# Description:
# Location:
# Following Count:301
# Follower Count:79
# Total Tweets:26199
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 80:
# Username:WellesbournCops
# Description:Police Safer Neighbourhoods Team for Wellesbourne. Please do not use Twitter to report crime, instead call 101 or, in an emergency, dial 999.
# Location:Wellesbourne
# Following Count:479
# Follower Count:1281
# Total Tweets:3139
# Retweet Count:5
# Tweet Text:Were you driving along Banbury Road in Lighthorne Heath around 5.45pm on Thursday? Did you witness an incident involving a Mini Cooper Sport and a white vehicle? Anyone with dashcam footage or information should call 101 quoting 287 of 10 December ➡️https://t.co/vQ53aCbX3g https://t.co/OrY0i1vWlw
# Hashtags Used:[]
#
# Tweet 81:
# Username:SportsManCo
# Description:Ihr kompetenter Ansprechpartner, wenn es um Tore, Netze & Co. geht ...
# Impressum: https://t.co/3eFGTMoHze
# Location:Düsseldorf | Deutschland
# Following Count:2578
# Follower Count:1296
# Total Tweets:1449
# Retweet Count:0
# Tweet Text:Scottish sport to benefit from £55m government funding package: https://t.co/aC6ZU9sw6S via @TicketTechForum
# Hashtags Used:[]
#
# Tweet 82:
# Username:Manuel_Perchas
# Description:Senior Content Editor @OneFootball. Antiguo coordinador @FCBVavel. Toda la actualidad del FC Barcelona y el Celta de Vigo a título personal. ✍🏻⚽️
# Location:Berlín, Alemania
# Following Count:1355
# Follower Count:637
# Total Tweets:15654
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 83:
# Username:syawal
# Description:“Everything should be made as simple as possible, but no simpler.” - Albert Einstein.
# RT or Like ≠ endorsement.
# Location:
# Following Count:4997
# Follower Count:2770
# Total Tweets:245000
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 84:
# Username:Julesmadworld
# Description:Hapless Brit waiting for the day Britain turns me into an illegal Alien & the French come knocking at my door to drag me by the feet & throw me back to England
# Location:Paris, France
# Following Count:5632
# Follower Count:5472
# Total Tweets:81489
# Retweet Count:385
# Tweet Text:I am delighted to announce that Hilton and Lundberg, 2020 is now published! @TLexercise
#
# ‘Transgender Women in the Female Category of Sport: Perspectives on Testosterone Suppression and Performance Advantage’
#
# https://t.co/GseD8W2rUp https://t.co/eJebU3rDhR
# Hashtags Used:[]
#
# Tweet 85:
# Username:JulienBecker100
# Description:Account Executive @salesforce. Keen on #digitaltechnologies and #travel
# Location:Paris, France
# Following Count:284
# Follower Count:756
# Total Tweets:47891
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 86:
# Username:Noidoromoo
# Description:Formerly Noidoromo_ (Got suspended for calling someone a turd lol). Freelance Writer for @WhatCulture
# Location:
# Following Count:112
# Follower Count:80
# Total Tweets:158
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 87:
# Username:__konstantin
# Description:User Research Lead @OneFootball - Social & Decision Making Psychologist - interested in how tech shapes humans and society. #ux #research #psychology #tech
# Location:Berlin
# Following Count:310
# Follower Count:161
# Total Tweets:337
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 88:
# Username:luismaryniok
# Description:Enthusiast of L'Escala anchovies & Content Lead at @OneFootball
# Location:Berlín, Alemania
# Following Count:194
# Follower Count:905
# Total Tweets:2684
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 89:
# Username:DIVYAAM_1979
# Description:Followed By @TcGehlotOffice @nsitharamanoffc @VijayGoelOffice @atifbjp @pmbjpbppi @prabinkp @BjpSarojini @pramodsworld1 @priyasethibjp @AsifBhamlaa
# Location:India
# Following Count:4505
# Follower Count:5731
# Total Tweets:314320
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 90:
# Username:DoKscho
# Description:
# Location:
# Following Count:80
# Follower Count:622
# Total Tweets:324213
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 91:
# Username:business
# Description:The first word in business news.
# Location:New York and the World
# Following Count:1298
# Follower Count:6833437
# Total Tweets:638180
# Retweet Count:14
# Tweet Text:Digital media group OneFootball agrees to buy a rival co-founded by 10 of the most powerful European soccer teams, amid increasing demand for behind-the-scenes content on the sport’s biggest names https://t.co/HWA8WCNWkx
# Hashtags Used:[]
#
# Tweet 92:
# Username:MichaelPhelps36
# Description:Tweeting about top fantasy Michael Phelps stories
# Location:Coventry
# Following Count:725
# Follower Count:710
# Total Tweets:8857
# Retweet Count:0
# Tweet Text:Asked how clean he thinks the Olympics will be next year, Michael Phelps says 'four or five' out of 10 - CNN International https://t.co/v0M84EBwp7
# Hashtags Used:[]
#
# Tweet 93:
# Username:Dish_Sport_Live
# Description:DISH KI DUNYA ME NUMBER ONE ID NEW CHANNELS NEW ALL KEYS ALL SPORTS UPDATES OR SUB KUCH AP KY LIYE
# FOLLOW @Dish_Sport_Live
# Send To 40404
# Location:KPK Lakki,Marwat Pakistan
# Following Count:50
# Follower Count:4475
# Total Tweets:40479
# Retweet Count:0
# Tweet Text:Wisden Test Team of the Year 2020
#
# 1) Dom Sibley 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 2) Shan Masood 🇵🇰
# 3) Kane Williamson 🇳🇿
# 4) Marnus Labuschagne 🇦🇺
# 5) Babar Azam 🇵🇰
# 6) Ben Stokes 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 7) Quinton De Kock 🇿🇦
# 8) Kyle Jamieson 🇳🇿
# 9) Stuart Broad 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 10) Tim Southee 🇳🇿
# 11) Nathan Lyon 🇦🇺
# +
# Follow @Dish_Sport_Live
# Hashtags Used:[]
#
# Tweet 94:
# Username:Dish_Sport_Live
# Description:DISH KI DUNYA ME NUMBER ONE ID NEW CHANNELS NEW ALL KEYS ALL SPORTS UPDATES OR SUB KUCH AP KY LIYE
# FOLLOW @Dish_Sport_Live
# Send To 40404
# Location:KPK Lakki,Marwat Pakistan
# Following Count:50
# Follower Count:4475
# Total Tweets:40479
# Retweet Count:0
# Tweet Text:KFC BIG-BASH_T20 2020/21
# ADS_🆚_HBH MATCH-08
# LIVE SCORE
# -
# Toss win on_ADS
#  &gt;Innings-Break&lt;
# HBH_146/10
# Ovr_19.3
# =
# Siddle 3.3-16-5W
# W Agar 4-28-2W
# Worrall 4-21-1W
# Rashid 4-27-1W
# Renshaw 2-30-0
# +
# Follow @Dish_Sport_Live https://t.co/l7Isi8glny
# Hashtags Used:[]
#
# Tweet 95:
# Username:Sport_Dish_Live
# Description:Follow me...........................................👆
# Location:
# Following Count:18
# Follower Count:143
# Total Tweets:266
# Retweet Count:2
# Tweet Text:LPL 2020 Top 10 Most Wicket Takers - Post Semi-Final Results.
#
# #LPL2020 #එක්වජයගමූ #wintogether #ஒன்றாகவெல்வோம் https://t.co/E3VWOlTRwW
# +
# @Sport_Dish_Live
# Hashtags Used:['LPL2020', 'එක්වජයගමූ', 'wintogether', 'ஒன்றாகவெல்வோம்']
#
# Tweet 96:
# Username:Sport_Dish_Live
# Description:Follow me...........................................👆
# Location:
# Following Count:18
# Follower Count:143
# Total Tweets:266
# Retweet Count:2
# Tweet Text:LPL 2020 Top 10 Most Run Scorers - Post Semi-Final Results.
#
# #LPL2020 #එක්වජයගමූ #wintogether #ஒன்றாகவெல்வோம் https://t.co/Tzk8SNErAM
# +
# @Sport_Dish_Live
# Hashtags Used:['LPL2020', 'එක්වජයගමූ', 'wintogether', 'ஒன்றாகவெல்வோம்']
#
# Tweet 97:
# Username:SasiVirat181
# Description:Virat Addictor 😍 Thalapathy Veriyan👊❤️
# Location:Jayankondam, India
# Following Count:58
# Follower Count:4
# Total Tweets:170
# Retweet Count:3
# Tweet Text:Jack Wildermuth is going OFF! He's got three already!
#
# 📺 Watch #BBL10 on Fox Cricket or💻 Stream on Kayo: https://t.co/anAenrOnnw
#
# 📱LIVE BLOG: https://t.co/6TtDj1KIiB https://t.co/RUlO1BOLss
# Hashtags Used:['BBL10']
#
# Tweet 98:
# Username:Dish_Sport_Live
# Description:DISH KI DUNYA ME NUMBER ONE ID NEW CHANNELS NEW ALL KEYS ALL SPORTS UPDATES OR SUB KUCH AP KY LIYE
# FOLLOW @Dish_Sport_Live
# Send To 40404
# Location:KPK Lakki,Marwat Pakistan
# Following Count:50
# Follower Count:4475
# Total Tweets:40479
# Retweet Count:2
# Tweet Text:LPL 2020 Top 10 Most Wicket Takers - Post Semi-Final Results.
#
# #LPL2020
#  https://t.co/uN8B02FD4u
# +
# Follow @Dish_Sport_Live
# Hashtags Used:['LPL2020']
#
# Tweet 99:
# Username:pageinextremis
# Description:Strategic communication agency, we build brands and strengthen the reputation of global corporations and leading international organisations. RT≠endorsement.
# Location:Brussels
# Following Count:1363
# Follower Count:460
# Total Tweets:15249
# Retweet Count:2
# Tweet Text:Referred to as a captain’s briefing, as pilots we need to make certain we have preloaded our brain with the contingencies and responses that might be needed early in flight. Read EAA Sport Aviation columnist Robert N. Rossier's latest piece here: https://t.co/5CASEwQ811 https://t.co/z2oNDBH9Ck
# Hashtags Used:[]
#
# Tweet 100:
# Username:Dish_Sport_Live
# Description:DISH KI DUNYA ME NUMBER ONE ID NEW CHANNELS NEW ALL KEYS ALL SPORTS UPDATES OR SUB KUCH AP KY LIYE
# FOLLOW @Dish_Sport_Live
# Send To 40404
# Location:KPK Lakki,Marwat Pakistan
# Following Count:50
# Follower Count:4475
# Total Tweets:40479
# Retweet Count:2
# Tweet Text:LPL 2020 Top 10 Most Run Scorers - Post Semi-Final Results.
#
# #LPL2020
#  https://t.co/a387it8K2y
# +
# Follow @Dish_Sport_Live
# Hashtags Used:['LPL2020']
#
# Tweet 101:
# Username:Alfaenshe
# Description:Red-Devil fan & a football freak pundit,#MUFC.Givin u d BEST sports Updates on Fotball & F1,News,Gossip. Racist dnt bother 2 follow m. Unfollow xpect d same bck
# Location:Leicester, United Kingdom
# Following Count:1704
# Follower Count:1552
# Total Tweets:197922
# Retweet Count:0
# Tweet Text:10 things we learned from the disrupted 2020 Formula One season
#  https://t.co/DO2VICaD4x
# Hashtags Used:[]
#
# Tweet 102:
# Username:CalFactCheck
# Description:Fact checking when the MSM won't. Retweets are NOT endorsements.
# Location:Los Angeles, CA
# Following Count:131
# Follower Count:1135
# Total Tweets:107655
# Retweet Count:1
# Tweet Text:#RadioJackie had a piece on #Tier3 regulations and mentioned about fans not being allowed at sporting events. This is only for “elite” sport so a small number of fans can go to local clubs, eg @CorinthianCas, @CHUFC &amp; @KingstonianFC
#
# #FactCheck
#
# https://t.co/1fnm8w8KEZ
# Hashtags Used:['RadioJackie', 'Tier3']
#
# Tweet 103:
# Username:RBKgreens
# Description:The Green Party Official Account in RB Kingston. 💙RTs not always endorsements: content on 3rd party sites not ours. #CommunityAction #WearAMask #BeBold
# ...
# Hashtags Used:[]
#
# Tweet 1961:
# Username:EdenSwimmer
# Description:Personal Views of a River Swimmer, Prof in Practice @CumbriaUni Passionate about Uplands & Commons @UplandsAlliance @4CommonLand, Trustee @Susans_Farm, Quaker🔸
# Location:Eden Valley, Cumbria
# Following Count:787
# Follower Count:739
# Total Tweets:2379
# Retweet Count:1
# Tweet Text:This is another v good piece on the issue, on the consequences for the professional game. More questions than answers at the moment but if football authorities can act re heading balls in schools there's no reason why rugby can't act too re tackling https://t.co/4YNdHiIe9c https://t.co/6VSVO50D8o
# Hashtags Used:[]
#
# Tweet 1962:
# Username:StephenHedges7
# Description:Author of 'The Player from Ponty'.  Sports history esp cricket. Swansea born. Co-presenter of CC4 Museum of Welsh Cricket Podcast
# All views my own
# Location:
# Following Count:2765
# Follower Count:874
# Total Tweets:11169
# Retweet Count:2
# Tweet Text:Kubrat Pulev might seem made for Anthony Joshua but the Bulgarian is serene and confident. He is also unexpectedly engaging. This is a first little piece with him about his belief that he will win and why all the talk about Fury could be Joshua's undoing. https://t.co/jyHwDBr9SQ
# Hashtags Used:[]
#
# Tweet 1963:
# Username:justicoahora
# Description:Ni antes ni despues, justico ahora
# Location:
# Following Count:364
# Follower Count:273
# Total Tweets:15637
# Retweet Count:11
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and tenpin bowling mishaps | Classic YouTube https://t.co/T43Bji2oyV
# Hashtags Used:[]
#
# Tweet 1964:
# Username:hairnova
# Description:Snapchat & Instagram: hairnova.
# Location:Halifax, NS
# Following Count:122
# Follower Count:132
# Total Tweets:31803
# Retweet Count:83
# Tweet Text:UPDATE | 7 players have been released from Canada’s National Junior Team Sport Chek Selection Camp.
#
# Goaltenders: Brett Brochu and Tristan Lennox
#
# Forwards: Adam Beckman, Tyson Foerster, Hendrix Lapierre, Cole Schwindt and Shane Wright
#
# More: https://t.co/XnoJZp61SF
# Hashtags Used:[]
#
# Tweet 1965:
# Username:OHAhockey1
# Description:The governing body for the majority of Junior and Senior hockey in Ontario. 116 teams across 4 leagues: ACH, OJHL, GOJHL and PJHL.
# Location:1425 Bishop St. Cambridge ON
# Following Count:791
# Follower Count:5927
# Total Tweets:16581
# Retweet Count:83
# Tweet Text:UPDATE | 7 players have been released from Canada’s National Junior Team Sport Chek Selection Camp.
#
# Goaltenders: Brett Brochu and Tristan Lennox
#
# Forwards: Adam Beckman, Tyson Foerster, Hendrix Lapierre, Cole Schwindt and Shane Wright
#
# More: https://t.co/XnoJZp61SF
# Hashtags Used:[]
#
# Tweet 1966:
# Username:guardian_sport
# Description:Sport news, comment, video and more from the @Guardian. For all your US sports needs, follow @GdnUSsports, and Australian sport @GdnAusSport. IG: guardian_sport
# Location:London
# Following Count:1767
# Follower Count:852625
# Total Tweets:220661
# Retweet Count:0
# Tweet Text:In today's Fiver: VAR strikes again. Plus Antonio Conte’s funk and a birthday surprise https://t.co/ax3mXCLg7b
# Hashtags Used:[]
#
# Tweet 1967:
# Username:NHL_RumorUpdate
# Description:Find the latest updates, news and rumors here!
# Location:
# Following Count:1174
# Follower Count:712
# Total Tweets:9505
# Retweet Count:83
# Tweet Text:UPDATE | 7 players have been released from Canada’s National Junior Team Sport Chek Selection Camp.
#
# Goaltenders: Brett Brochu and Tristan Lennox
#
# Forwards: Adam Beckman, Tyson Foerster, Hendrix Lapierre, Cole Schwindt and Shane Wright
#
# More: https://t.co/XnoJZp61SF
# Hashtags Used:[]
#
# Tweet 1968:
# Username:ChochilinoRadio
# Description:
# Location:
# Following Count:27
# Follower Count:94
# Total Tweets:290623
# Retweet Count:0
# Tweet Text:Champions League Review: Running the rule over Africa’s stars in the Group Stage https://t.co/kU0jHm1uHN
# Hashtags Used:[]
#
# Tweet 1969:
# Username:nic_stpierre
# Description:Animateur de l’émission, Dans le vestiaire et descripteur francophone Sénateurs d'Ottawa, @945UNIQUEFM + Hockey LHJMQ @tvROttawa. Surtout fier papa.
# Location:Ottawa, Canada
# Following Count:874
# Follower Count:1878
# Total Tweets:12903
# Retweet Count:83
# Tweet Text:UPDATE | 7 players have been released from Canada’s National Junior Team Sport Chek Selection Camp.
#
# Goaltenders: Brett Brochu and Tristan Lennox
#
# Forwards: Adam Beckman, Tyson Foerster, Hendrix Lapierre, Cole Schwindt and Shane Wright
#
# More: https://t.co/XnoJZp61SF
# Hashtags Used:[]
#
# Tweet 1970:
# Username:NewsNetworks5
# Description:Blogger 🗺 news world & 📷 photography of events nationwide & around the globe 🌎 opinions & direct messages are welcome👌 tweets & retweets!
# Location:
# Following Count:383
# Follower Count:196
# Total Tweets:1728
# Retweet Count:371
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/0HJkQROuyP https://t.co/b79N5b3a6a
# Hashtags Used:[]
#
# Tweet 1971:
# Username:ChochilinoRadio
# Description:
# Location:
# Following Count:27
# Follower Count:94
# Total Tweets:290623
# Retweet Count:0
# Tweet Text:East Bengal 0-0 Jamshedpur: 10-man Red and Golds hold out for a draw https://t.co/jNWcVTwVYa
# Hashtags Used:[]
#
# Tweet 1972:
# Username:ChochilinoRadio
# Description:
# Location:
# Following Count:27
# Follower Count:94
# Total Tweets:290623
# Retweet Count:0
# Tweet Text:Pelembe: Ex-Mamelodi Sundowns winger reveals offer from PSL club https://t.co/JnZSU8r3ai
# Hashtags Used:[]
#
# Tweet 1973:
# Username:ChochilinoRadio
# Description:
# Location:
# Following Count:27
# Follower Count:94
# Total Tweets:290623
# Retweet Count:0
# Tweet Text:Bayern Munich dominate 2020 FIFPRO Men’s World XI nominations with nine candidates https://t.co/Y5REPQXkXp
# Hashtags Used:[]
#
# Tweet 1974:
# Username:ChochilinoRadio
# Description:
# Location:
# Following Count:27
# Follower Count:94
# Total Tweets:290623
# Retweet Count:0
# Tweet Text:African Football HQ Podcast: Can La Liga eclipse the Premier League in Africa? https://t.co/k0mhx7WQK5
# Hashtags Used:[]
#
# Tweet 1975:
# Username:bovainmacnab
# Description:Family, Friends, Mountains, Beaches, Starting Building and Fixing Organizations, Housing For All, Fun, Travel, Africa, Political Economy, (Economic) History
# Location:
# Following Count:562
# Follower Count:368
# Total Tweets:15385
# Retweet Count:0
# Tweet Text:More woes for Western Province rugby with damages claim lodged against the union
#
# https://t.co/cpqCsn90YV
# Hashtags Used:[]
#
# Tweet 1976:
# Username:KiddDynamite94
# Description:
# Location:
# Following Count:1336
# Follower Count:313
# Total Tweets:6846
# Retweet Count:371
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/0HJkQROuyP https://t.co/b79N5b3a6a
# Hashtags Used:[]
#
# Tweet 1977:
# Username:BurritosSteak
# Description:Burritos Steak Gourmet
# Location:
# Following Count:821
# Follower Count:214
# Total Tweets:40380
# Retweet Count:11
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and tenpin bowling mishaps | Classic YouTube https://t.co/T43Bji2oyV
# Hashtags Used:[]
#
# Tweet 1978:
# Username:raunphuwr
# Description:Twitter account
# Location:ประเทศไทย
# Following Count:40
# Follower Count:1
# Total Tweets:53805
# Retweet Count:371
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/0HJkQROuyP https://t.co/b79N5b3a6a
# Hashtags Used:[]
#
# Tweet 1979:
# Username:mikeystvff
# Description:Grow with the flow
# Location:
# Following Count:414
# Follower Count:34
# Total Tweets:685
# Retweet Count:371
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/0HJkQROuyP https://t.co/b79N5b3a6a
# Hashtags Used:[]
#
# Tweet 1980:
# Username:RDAbyronhackett
# Description:“The only thing that sports gives us is moments. But what the hell is life, Peter, apart from moments?” - Beartown
# Location:Red Deer, Alberta
# Following Count:1249
# Follower Count:986
# Total Tweets:28300
# Retweet Count:83
# Tweet Text:UPDATE | 7 players have been released from Canada’s National Junior Team Sport Chek Selection Camp.
#
# Goaltenders: Brett Brochu and Tristan Lennox
#
# Forwards: Adam Beckman, Tyson Foerster, Hendrix Lapierre, Cole Schwindt and Shane Wright
#
# More: https://t.co/XnoJZp61SF
# Hashtags Used:[]
# Tweet 1981:
# Username:MotoChicGear
# Description:Stylish Gear for Women on the Move
# Location:Los Gatos, CA - south of SF
# Following Count:409
# Follower Count:315
# Total Tweets:1732
# Retweet Count:1
# Tweet Text:We are thrilled the Lauren Sport is featured in the "Top 10 Luxury Travel Gifts" on @luxurytravel
# Check it out along with some really great ideas for treating the ladies in your life!
# https://t.co/hCmEqXL0wH https://t.co/4CnCO2gRO1
# Hashtags Used:[]
#
# Tweet 1982:
# Username:guardian_sport
# Description:Sport news, comment, video and more from the @Guardian. For all your US sports needs, follow @GdnUSsports, and Australian sport @GdnAusSport. IG: guardian_sport
# Location:London
# Following Count:1767
# Follower Count:852625
# Total Tweets:220661
# Retweet Count:2
# Tweet Text:Europa League: Dundalk v Arsenal, Lech Poznan v Rangers and more – live! Join @bglendenning https://t.co/Cb2v5M9WBj
# Hashtags Used:[]
#
# Tweet 1983:
# Username:Chintu036879599
# Description:#JAY_SRI_RAM
# Location:
# Following Count:1078
# Follower Count:410
# Total Tweets:27379
# Retweet Count:11
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and tenpin bowling mishaps | Classic YouTube https://t.co/T43Bji2oyV
# Hashtags Used:[]
#
# Tweet 1984:
# Username:JoergAuberg
# Description:Writer, critic, editor, publisher, book collector, archivist, software developer (Lotus Notes, .NET)
# Location:Wesel
# Following Count:392
# Follower Count:15
# Total Tweets:946
# Retweet Count:11
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and tenpin bowling mishaps | Classic YouTube https://t.co/T43Bji2oyV
# Hashtags Used:[]
#
# Tweet 1985:
# Username:GarangiS
# Description:
# Location:
# Following Count:224
# Follower Count:8
# Total Tweets:20853
# Retweet Count:11
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and tenpin bowling mishaps | Classic YouTube https://t.co/T43Bji2oyV
# Hashtags Used:[]
#
# Tweet 1986:
# Username:robertdolci
# Description:Keen on #digitaltransformation, #AI, #IIOT, Lucky hubbie of @LdalessandroMBA, #ProudDad,  #Triathlete
# Location:Boston, MA
# Following Count:1708
# Follower Count:1779
# Total Tweets:17020
# Retweet Count:11
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and tenpin bowling mishaps | Classic YouTube https://t.co/T43Bji2oyV
# Hashtags Used:[]
#
# Tweet 1987:
# Username:timwalker919
# Description:Maritime Project Leader and Senior Researcher - Institute for Security Studies @issafrica - Tweeting in own capacity, RTs are not an endorsement
# Location:ISS Pretoria
# Following Count:2885
# Follower Count:1261
# Total Tweets:8474
# Retweet Count:0
# Tweet Text:Rugby's dementia plight exposes a chilling sting in the game's tail | Robert Kitson https://t.co/Moj98NdjpT
# Hashtags Used:[]
#
# Tweet 1988:
# Username:ManutdMMM
# Description:
# Location:Earth
# Following Count:3820
# Follower Count:399
# Total Tweets:37897
# Retweet Count:371
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/0HJkQROuyP https://t.co/b79N5b3a6a
# Hashtags Used:[]
#
# Tweet 1989:
# Username:LaffEnterprises
# Description:
# Location:Greenfield, IN
# Following Count:23
# Follower Count:3
# Total Tweets:95
# Retweet Count:11
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and tenpin bowling mishaps | Classic YouTube https://t.co/T43Bji2oyV
# Hashtags Used:[]
#
# Tweet 1990:
# Username:EastlinkKevin
# Description:Producer: Eastlink Community TV. Play-by-play for QMJHL Friday Night Hockey, MHL, NSEMMHL, NSSAF and more!
# Location:Halifax, Nova Scotia
# Following Count:939
# Follower Count:1422
# Total Tweets:10146
# Retweet Count:83
# Tweet Text:UPDATE | 7 players have been released from Canada’s National Junior Team Sport Chek Selection Camp.
#
# Goaltenders: Brett Brochu and Tristan Lennox
#
# Forwards: Adam Beckman, Tyson Foerster, Hendrix Lapierre, Cole Schwindt and Shane Wright
#
# More: https://t.co/XnoJZp61SF
# Hashtags Used:[]
#
# Tweet 1991:
# Username:grauniad_news
# Description:A twitter bot which tweets @guardian tweets with spelling mistakes. The bot is not smart enough to determine when such spelling mistakes may appear insensitive.
# Location:
# Following Count:0
# Follower Count:221
# Total Tweets:324453
# Retweet Count:0
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and etnpin bowling mishaps | Clissac YouTube https://t.co/rbyG142mh9
# Hashtags Used:[]
#
# Tweet 1992:
# Username:guardian
# Description:The need for independent journalism has never been greater. Become a Guardian supporter: https://t.co/gWyuUVlObq
# Location:London
# Following Count:1083
# Follower Count:9370889
# Total Tweets:643879
# Retweet Count:11
# Tweet Text:A Paolo Rossi tribute, the best of Peter Alliss and tenpin bowling mishaps | Classic YouTube https://t.co/T43Bji2oyV
# Hashtags Used:[]
#
# Tweet 1993:
# Username:OfficialTFSport
# Description:⬡16,17,18,19 & 20 British GT Champions ⬡17, 19 Blancpain Champions ⁣ ⬡19 Spa 24H Winner⁣ ⬡19/20 WEC Fuji, Shanghai, COTA, Le Mans 24H Winners⁣
# Location:Slinfold, England
# Following Count:563
# Follower Count:7016
# Total Tweets:9251
# Retweet Count:6
# Tweet Text:TF Sport to made IMSA debut at Rolex 24 https://t.co/SkxUc2nC2D via @racermag
# Hashtags Used:[]
#
# Tweet 1994:
# Username:curly_grace
# Description:Who stole the cookie from the cookie jar? who? me?....yes! YOU!
# Location:victoria, australia
# Following Count:183
# Follower Count:94
# Total Tweets:7027
# Retweet Count:371
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/0HJkQROuyP https://t.co/b79N5b3a6a
# Hashtags Used:[]
#
# Tweet 1995:
# Username:Libertea2012
# Description:Progressive policies are the only remedy to the sickness of the current system. RTs NOT ENDORSEMENTS
# Location:ProgressiveLand
# Following Count:23003
# Follower Count:49335
# Total Tweets:644430
# Retweet Count:0
# Tweet Text:US Olympic Committee won't discipline protesting athletes in snub to IOC https://t.co/gt2ZTJqYqM
# Hashtags Used:[]
#
# Tweet 1996:
# Username:PatenaudeSerge
# Description:wdym Chief Keef ain’t about this or that
# Location:Ottawa, Ontario
# Following Count:430
# Follower Count:147
# Total Tweets:1165
# Retweet Count:83
# Tweet Text:UPDATE | 7 players have been released from Canada’s National Junior Team Sport Chek Selection Camp.
#
# Goaltenders: Brett Brochu and Tristan Lennox
#
# Forwards: Adam Beckman, Tyson Foerster, Hendrix Lapierre, Cole Schwindt and Shane Wright
#
# More: https://t.co/XnoJZp61SF
# Hashtags Used:[]
#
# Tweet 1997:
# Username:MiBebaYadi
# Description:XO til we OD IG:mibebayadi
# Location:
# Following Count:496
# Follower Count:431
# Total Tweets:17465
# Retweet Count:371
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/0HJkQROuyP https://t.co/b79N5b3a6a
# Hashtags Used:[]
#
# Tweet 1998:
# Username:SPCockrill
# Description:"Scratch any cynic and you will find a disappointed idealist."
# - George Carlin
#
#   Artist and musician.
# Location:
# Following Count:509
# Follower Count:279
# Total Tweets:2053
# Retweet Count:15
# Tweet Text:Dementia link leads to calls for collision rugby to be banned in schools https://t.co/ZHtOiDO6XG
# Hashtags Used:[]
#
# Tweet 1999:
# Username:JCLCommodities
# Description:
# Location:
# Following Count:655
# Follower Count:297
# Total Tweets:13466
# Retweet Count:83
# Tweet Text:UPDATE | 7 players have been released from Canada’s National Junior Team Sport Chek Selection Camp.
#
# Goaltenders: Brett Brochu and Tristan Lennox
#
# Forwards: Adam Beckman, Tyson Foerster, Hendrix Lapierre, Cole Schwindt and Shane Wright
#
# More: https://t.co/XnoJZp61SF
# Hashtags Used:[]
#
# Tweet 2000:
# Username:aGirlyLadybug
# Description:Chocoholic ❤ Books ,Music ,Movies ,Shopping ,Starbucks ❤ Dakota Johnson, Jamie Dornan, Robert Pattinson, Chris Evans stan.. Jack Sparrow should be real, Yo Ho ♫
# Location:The World
# Following Count:383
# Follower Count:392
# Total Tweets:143117
# Retweet Count:371
# Tweet Text:Los Angeles Lakers star LeBron James has been named TIME magazine's Athlete of the Year https://t.co/0HJkQROuyP https://t.co/b79N5b3a6a
# Hashtags Used:[]
# Scraping has completed!

# %% [markdown]
# ##### On va afficher les données de chaque tweet

# %%
# function to display data of each tweet 
def printtweetdata(n, ith_tweet): 
    print() 
    print(f"Tweet {n}:") 
    print(f"Username:{ith_tweet[0]}") 
    print(f"Description:{ith_tweet[1]}") 
    print(f"Location:{ith_tweet[2]}") 
    print(f"Following Count:{ith_tweet[3]}") 
    print(f"Follower Count:{ith_tweet[4]}") 
    print(f"Total Tweets:{ith_tweet[5]}") 
    print(f"Retweet Count:{ith_tweet[6]}") 
    print(f"Tweet Text:{ith_tweet[7]}") 
    print(f"Hashtags Used:{ith_tweet[8]}")

# %% [markdown]
# ##### on va lire les deux fichier dataset puis les concaténer ensemble dans un autre fichier df_final

# %%
df_1= pd.read_csv('tweets1.csv')
df=pd.read_csv('tweets.csv')
df_final=pd.concat([df, df_1], ignore_index=True)
print(df_final.shape)
df_final.head()
# Out:
# (4000, 10)
#    Unnamed: 0         username  \
# 0           0      YOYO_SYorks
# 1           1  aatschilperoort
# 2           2     NotFanucules
# 3           3   FrontPubHealth
# 4           4     ukantidoping
#
#                                          description               location  \
# 0                YOYO Sport - You're Only Young Once        South Yorkshire
# 1  personal trainer strong selfdefence® 9th dan (...  Netherlands, Germany
# 2                             unapologetically white                    NaN
# 3  The official Twitter Feed for all the latest o...  Lausanne, Switzerland
# 4  UKAD is the National Anti-Doping Organisation ...                 London
#
#    following  followers  totaltweets  retweetcount  \
# 0         57        328         1207             0
# 1        368        138         5362             3
# 2         60         37         1067             0
# 3       2381       3737         3466             0
# 4        528      17605         8178             3
#
#                                                 text  \
# 0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session b...
# 1  As part of the new @wada_ama 2021 World Anti-D...
# 2  @IIWolfe1 @Justin420451408 @GBlattenberger @or...
# 3  New Research: Cardiorespiratory Fitness Is Ass...
# 4  As part of the new @wada_ama 2021 World Anti-D...
#
#                            hashtags
# 0                                []
# 1                                []
# 2                                []
# 3  ['PublicHealth', 'HealthForAll']
# 4                                []

# %%
print(df.shape)
print(df_1.shape)
# Out:
# (2000, 10)
# (2000, 10)

# %% [markdown]
# ### On va éliminer les colonnes dans la liste de to_drop du dataframe

# %%
to_drop = ['Unnamed: 0',
           'username',
           'description',
           'location',
           'following',
           'followers',
           'totaltweets']
#Eliminer les colonnes dans la liste de to_drop du dataframe df
df.drop(to_drop, inplace=True, axis=1)
#Afficherle résultat
df.head()
# Out:
#    retweetcount                                               text  \
# 0             0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session b...
# 1             3  As part of the new @wada_ama 2021 World Anti-D...
# 2             0  @IIWolfe1 @Justin420451408 @GBlattenberger @or...
# 3             0  New Research: Cardiorespiratory Fitness Is Ass...
# 4             3  As part of the new @wada_ama 2021 World Anti-D...
#
#                            hashtags
# 0                                []
# 1                                []
# 2                                []
# 3  ['PublicHealth', 'HealthForAll']
# 4                                []

# %% [markdown]
# ## Prétraitement
#
# Les tweets contiennent des objets inutiles tels que des hashtags, des mentions, des liens et des signes de ponctuation qui peuvent affecter les performances d'un algorithme et doivent donc être supprimés. Tous les textes sont convertis en minuscules pour éviter que les algorithmes n'interprètent les mêmes mots avec des cas différents comme différents

# %%
import string , re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### On va maintenant supprimez les hashtags, les mentions et les caractères indésirables.

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def ponctuation_sup(text_entree):
    text_entree = "".join([char for char in text_entree if char not in string.punctuation])
    text_entree = re.sub('[0-9]+', '', text_entree)
    
    return text_entree

df['Tweet_punctuation'] = df['text'].apply(lambda x: ponctuation_sup(x))
df.head(10)
# Out:
#    retweetcount                                               text  \
# 0             0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session b...
# 1             3  As part of the new @wada_ama 2021 World Anti-D...
# 2             0  @IIWolfe1 @Justin420451408 @GBlattenberger @or...
# 3             0  New Research: Cardiorespiratory Fitness Is Ass...
# 4             3  As part of the new @wada_ama 2021 World Anti-D...
# 5             3  As part of the new @wada_ama 2021 World Anti-D...
# 6            14  Here's one  recent poll showing how football i...
# 7             3  As part of the new @wada_ama 2021 World Anti-D...
# 8             0  @drnngujarathi @IamShajanSamuel @SandeepMall Y...
# 9             3  @RocesterFC1876 @FA @MidlandLeague @CommonsDCM...
#
#                            hashtags  \
# 0                                []
# 1                                []
# 2                                []
# 3  ['PublicHealth', 'HealthForAll']
# 4                                []
# 5                                []
# 6                                []
# 7                                []
# 8                                []
# 9                                []
#
#                                    Tweet_punctuation
# 0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final YOYOSYorks session bef...
# 1  As part of the new wadaama  World AntiDoping C...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  New Research Cardiorespiratory Fitness Is Asso...
# 4  As part of the new wadaama  World AntiDoping C...
# 5  As part of the new wadaama  World AntiDoping C...
# 6  Heres one  recent poll showing how football is...
# 7  As part of the new wadaama  World AntiDoping C...
# 8  drnngujarathi IamShajanSamuel SandeepMall Your...
# 9  RocesterFC FA MidlandLeague CommonsDCMS The FA...

# %% [markdown]
# ### Tokenisation, lemmatisation et suppression des mots vides

# %% [markdown]
# #### La tokenisation cherche à transformer un texte en une série de tokens individuels. Dans l’idée, chaque token représente un mot, et identifier des mots semble être une tâche relativement simple.

# %%
df['Tweet_no_mot'] = df['Tweet_punctuation'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
def tokenization(text):
    text = re.split(' ', text)
    return text

df['Tweet_tokenized'] = df['Tweet_no_mot'].apply(lambda x: tokenization(x.lower()))

df.head()
# Out:
#    retweetcount                                               text  \
# 0             0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session b...
# 1             3  As part of the new @wada_ama 2021 World Anti-D...
# 2             0  @IIWolfe1 @Justin420451408 @GBlattenberger @or...
# 3             0  New Research: Cardiorespiratory Fitness Is Ass...
# 4             3  As part of the new @wada_ama 2021 World Anti-D...
#
#                            hashtags  \
# 0                                []
# 1                                []
# 2                                []
# 3  ['PublicHealth', 'HealthForAll']
# 4                                []
#
#                                    Tweet_punctuation  \
# 0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final YOYOSYorks session bef...
# 1  As part of the new wadaama  World AntiDoping C...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  New Research Cardiorespiratory Fitness Is Asso...
# 4  As part of the new wadaama  World AntiDoping C...
#
#                                         Tweet_no_mot  \
# 0  𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 final YOYOSYorks session before Chris...
# 1  part wadaama World AntiDoping Code from sport ...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  Research Cardiorespiratory Fitness Associated ...
# 4  part wadaama World AntiDoping Code from sport ...
#
#                                      Tweet_tokenized
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, before,...
# 1  [part, wadaama, world, antidoping, code, from,...
# 2  [iiwolfe, justin, gblattenberger, ormelling, b...
# 3  [research, cardiorespiratory, fitness, associa...
# 4  [part, wadaama, world, antidoping, code, from,...

# %%
df['Tweet_tokenized'] = df['Tweet_no_mot'].apply(lambda x: tokenization(x.lower()))

df.head()
# Out:
#    retweetcount                                               text  \
# 0             0  @TulsiGabbard the biological essentialism of T...
# 1             1  mighty funny how nobody in black sports media ...
# 2             0  Tht time I was put in a gc full of barstool sp...
# 3             1  mighty funny how nobody in black sports media ...
# 4             0  @DanSoder @katienolan that Andre AD read made ...
#
#      hashtags                                  Tweet_punctuation  \
# 0          []  TulsiGabbard the biological essentialism of TE...
# 1          []  mighty funny how nobody in black sports media ...
# 2          []  Tht time I was put in a gc full of barstool sp...
# 3          []  mighty funny how nobody in black sports media ...
# 4  ['sports']  DanSoder katienolan that Andre AD read made me...
#
#                                         Tweet_no_mot  \
# 0  TulsiGabbard biological essentialism TERFs fun...
# 1  mighty funny nobody black sports media standin...
# 2  time full barstool sports type funny accounts ...
# 3  mighty funny nobody black sports media standin...
# 4  DanSoder katienolan that Andre read made swerv...
#
#                                      Tweet_tokenized
# 0  [tulsigabbard, biological, essentialism, terfs...
# 1  [mighty, funny, nobody, black, sports, media, ...
# 2  [time, full, barstool, sports, type, funny, ac...
# 3  [mighty, funny, nobody, black, sports, media, ...
# 4  [dansoder, katienolan, that, andre, read, made...

# %% [markdown]
# On vas utiliser la bibliothèque NLTK pour effectuer une analyse de chaque tweet et le transformer en un ensemble de mots en suivant les différentes étapes de base du processus NLP (Natural Language Processing)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\nouha\anaconda\lib\site-packages (3.4.4)
# Requirement already satisfied: six in c:\users\nouha\anaconda\lib\site-packages (from nltk) (1.12.0)

# %%
import nltk
nltk.download('stopwords')
stopword = nltk.corpus.stopwords.words('english')
print(stopword)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nouha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text):
    text = [word for word in text if word not in stopword]
    return text
    
df['Tweet_words'] = df['Tweet_tokenized'].apply(lambda x: remove_stopwords(x))
df.head(10)
# Out:
#    retweetcount                                               text  \
# 0             0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session b...
# 1             3  As part of the new @wada_ama 2021 World Anti-D...
# 2             0  @IIWolfe1 @Justin420451408 @GBlattenberger @or...
# 3             0  New Research: Cardiorespiratory Fitness Is Ass...
# 4             3  As part of the new @wada_ama 2021 World Anti-D...
# 5             3  As part of the new @wada_ama 2021 World Anti-D...
# 6            14  Here's one  recent poll showing how football i...
# 7             3  As part of the new @wada_ama 2021 World Anti-D...
# 8             0  @drnngujarathi @IamShajanSamuel @SandeepMall Y...
# 9             3  @RocesterFC1876 @FA @MidlandLeague @CommonsDCM...
#
#                            hashtags  \
# 0                                []
# 1                                []
# 2                                []
# 3  ['PublicHealth', 'HealthForAll']
# 4                                []
# 5                                []
# 6                                []
# 7                                []
# 8                                []
# 9                                []
#
#                                    Tweet_punctuation  \
# 0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final YOYOSYorks session bef...
# 1  As part of the new wadaama  World AntiDoping C...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  New Research Cardiorespiratory Fitness Is Asso...
# 4  As part of the new wadaama  World AntiDoping C...
# 5  As part of the new wadaama  World AntiDoping C...
# 6  Heres one  recent poll showing how football is...
# 7  As part of the new wadaama  World AntiDoping C...
# 8  drnngujarathi IamShajanSamuel SandeepMall Your...
# 9  RocesterFC FA MidlandLeague CommonsDCMS The FA...
#
#                                         Tweet_no_mot  \
# 0  𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 final YOYOSYorks session before Chris...
# 1  part wadaama World AntiDoping Code from sport ...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  Research Cardiorespiratory Fitness Associated ...
# 4  part wadaama World AntiDoping Code from sport ...
# 5  part wadaama World AntiDoping Code from sport ...
# 6  Heres recent poll showing football replacing u...
# 7  part wadaama World AntiDoping Code from sport ...
# 8  drnngujarathi IamShajanSamuel SandeepMall Your...
# 9  RocesterFC MidlandLeague CommonsDCMS DCMS have...
#
#                                      Tweet_tokenized  \
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, before,...
# 1  [part, wadaama, world, antidoping, code, from,...
# 2  [iiwolfe, justin, gblattenberger, ormelling, b...
# 3  [research, cardiorespiratory, fitness, associa...
# 4  [part, wadaama, world, antidoping, code, from,...
# 5  [part, wadaama, world, antidoping, code, from,...
# 6  [heres, recent, poll, showing, football, repla...
# 7  [part, wadaama, world, antidoping, code, from,...
# 8  [drnngujarathi, iamshajansamuel, sandeepmall, ...
# 9  [rocesterfc, midlandleague, commonsdcms, dcms,...
#
#                                          Tweet_words
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, christm...
# 1  [part, wadaama, world, antidoping, code, sport...
# 2  [iiwolfe, justin, gblattenberger, ormelling, b...
# 3  [research, cardiorespiratory, fitness, associa...
# 4  [part, wadaama, world, antidoping, code, sport...
# 5  [part, wadaama, world, antidoping, code, sport...
# 6  [heres, recent, poll, showing, football, repla...
# 7  [part, wadaama, world, antidoping, code, sport...
# 8  [drnngujarathi, iamshajansamuel, sandeepmall, ...
# 9  [rocesterfc, midlandleague, commonsdcms, dcms,...

# %% [markdown]
# Le stemming consiste à réduire un mot dans sa forme « racine ». Le but du stemming est de regrouper de nombreuses variantes d’un mot comme un seul et même mot. Par exemple, une fois que l’on applique un stemming sur « Chiens » ou « Chien », le mot résultant est le même.

# %%
ps = nltk.PorterStemmer()
def stemming(text):
    text = [ps.stem(word) for word in text]
    return text

df['Tweet_stemmed'] = df['Tweet_words'].apply(lambda x: stemming(x))
df.head()
# Out:
#    retweetcount                                               text  \
# 0             0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session b...
# 1             3  As part of the new @wada_ama 2021 World Anti-D...
# 2             0  @IIWolfe1 @Justin420451408 @GBlattenberger @or...
# 3             0  New Research: Cardiorespiratory Fitness Is Ass...
# 4             3  As part of the new @wada_ama 2021 World Anti-D...
#
#                            hashtags  \
# 0                                []
# 1                                []
# 2                                []
# 3  ['PublicHealth', 'HealthForAll']
# 4                                []
#
#                                    Tweet_punctuation  \
# 0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final YOYOSYorks session bef...
# 1  As part of the new wadaama  World AntiDoping C...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  New Research Cardiorespiratory Fitness Is Asso...
# 4  As part of the new wadaama  World AntiDoping C...
#
#                                         Tweet_no_mot  \
# 0  𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 final YOYOSYorks session before Chris...
# 1  part wadaama World AntiDoping Code from sport ...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  Research Cardiorespiratory Fitness Associated ...
# 4  part wadaama World AntiDoping Code from sport ...
#
#                                      Tweet_tokenized  \
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, before,...
# 1  [part, wadaama, world, antidoping, code, from,...
# 2  [iiwolfe, justin, gblattenberger, ormelling, b...
# 3  [research, cardiorespiratory, fitness, associa...
# 4  [part, wadaama, world, antidoping, code, from,...
#
#                                          Tweet_words  \
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, christm...
# 1  [part, wadaama, world, antidoping, code, sport...
# 2  [iiwolfe, justin, gblattenberger, ormelling, b...
# 3  [research, cardiorespiratory, fitness, associa...
# 4  [part, wadaama, world, antidoping, code, sport...
#
#                                        Tweet_stemmed
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyork, session, christma...
# 1  [part, wadaama, world, antidop, code, sport, e...
# 2  [iiwolf, justin, gblattenberg, ormel, bgonthes...
# 3  [research, cardiorespiratori, fit, associ, dro...
# 4  [part, wadaama, world, antidop, code, sport, e...

# %% [markdown]
# La stemming et la lemmatisation sont des techniques de normalisation de texte (ou parfois appelées normalisation de mots ) dans le domaine du traitement du langage naturel qui sont utilisées pour préparer du texte, des mots et des documents pour un traitement ultérieur.

# %%
nltk.download('wordnet')
wn = nltk.WordNetLemmatizer()

def lemmatizer(text):
    text = [wn.lemmatize(word) for word in text]
    return text

df['Tweet_lemmatized'] = df['Tweet_words'].apply(lambda x: lemmatizer(x))
df.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nouha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#    retweetcount                                               text  \
# 0             0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final @YOYO_SYorks session b...
# 1             3  As part of the new @wada_ama 2021 World Anti-D...
# 2             0  @IIWolfe1 @Justin420451408 @GBlattenberger @or...
# 3             0  New Research: Cardiorespiratory Fitness Is Ass...
# 4             3  As part of the new @wada_ama 2021 World Anti-D...
#
#                            hashtags  \
# 0                                []
# 1                                []
# 2                                []
# 3  ['PublicHealth', 'HealthForAll']
# 4                                []
#
#                                    Tweet_punctuation  \
# 0  🎄 𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 is our final YOYOSYorks session bef...
# 1  As part of the new wadaama  World AntiDoping C...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  New Research Cardiorespiratory Fitness Is Asso...
# 4  As part of the new wadaama  World AntiDoping C...
#
#                                         Tweet_no_mot  \
# 0  𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖 final YOYOSYorks session before Chris...
# 1  part wadaama World AntiDoping Code from sport ...
# 2  IIWolfe Justin GBlattenberger ormelling BGOnTh...
# 3  Research Cardiorespiratory Fitness Associated ...
# 4  part wadaama World AntiDoping Code from sport ...
#
#                                      Tweet_tokenized  \
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, before,...
# 1  [part, wadaama, world, antidoping, code, from,...
# 2  [iiwolfe, justin, gblattenberger, ormelling, b...
# 3  [research, cardiorespiratory, fitness, associa...
# 4  [part, wadaama, world, antidoping, code, from,...
#
#                                          Tweet_words  \
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, christm...
# 1  [part, wadaama, world, antidoping, code, sport...
# 2  [iiwolfe, justin, gblattenberger, ormelling, b...
# 3  [research, cardiorespiratory, fitness, associa...
# 4  [part, wadaama, world, antidoping, code, sport...
#
#                                        Tweet_stemmed  \
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyork, session, christma...
# 1  [part, wadaama, world, antidop, code, sport, e...
# 2  [iiwolf, justin, gblattenberg, ormel, bgonthes...
# 3  [research, cardiorespiratori, fit, associ, dro...
# 4  [part, wadaama, world, antidop, code, sport, e...
#
#                                     Tweet_lemmatized
# 0  [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, christm...
# 1  [part, wadaama, world, antidoping, code, sport...
# 2  [iiwolfe, justin, gblattenberger, ormelling, b...
# 3  [research, cardiorespiratory, fitness, associa...
# 4  [part, wadaama, world, antidoping, code, sport...

# %%
df.Tweet_lemmatized
# Out:
# 0       [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, christm...
# 1       [part, wadaama, world, antidoping, code, sport...
# 2       [iiwolfe, justin, gblattenberger, ormelling, b...
# 3       [research, cardiorespiratory, fitness, associa...
# 4       [part, wadaama, world, antidoping, code, sport...
# 5       [part, wadaama, world, antidoping, code, sport...
# 6       [here, recent, poll, showing, football, replac...
# 7       [part, wadaama, world, antidoping, code, sport...
# 8       [drnngujarathi, iamshajansamuel, sandeepmall, ...
# 9       [rocesterfc, midlandleague, commonsdcms, dcms,...
# 10      [december, dubai, reuters, doha, beat, riyadh,...
# 11      [here, recent, poll, showing, football, replac...
# 12      [rocesterfc, midlandleague, commonsdcms, dcms,...
# 13      [here, recent, poll, showing, football, replac...
# 14      [here, recent, poll, showing, football, replac...
# 15      [childhood, adolescent, coachled, multisport, ...
# 16      [rocesterfc, midlandleague, commonsdcms, dcms,...
# 17      [bash, league, today, match, abonded, rain, sc...
# 18      [angeles, lakers, star, lebron, james, named, ...
# 19      [interdisciplinary, examination, stress, injur...
# 20      [here, recent, poll, showing, football, replac...
# 21      [here, recent, poll, showing, football, replac...
# 22      [icymi, telford, netted, coleshill, buck, http...
# 23      [𝐓𝐎𝐌𝐎𝐑𝐑𝐎𝐖, final, yoyosyorks, session, christm...
# 24      [ijsppjournal, editorial, davidtmartin, ‘facto...
# 25      [here, recent, poll, showing, football, replac...
# 26      [here, recent, poll, showing, football, replac...
# 27      [here, recent, poll, showing, football, replac...
# 28      [here, recent, poll, showing, football, replac...
# 29      [here, recent, poll, showing, football, replac...
#                               ...
# 1970    [east, bengal, jamshedpur, gold, hold, draw, h...
# 1971    [pelembe, exmamelodi, sundown, winger, reveals...
# 1972    [bayern, munich, dominate, fifpro, men’s, worl...
# 1973    [african, football, podcast, liga, eclipse, pr...
# 1974    [woe, western, province, rugby, damage, claim,...
# 1975    [angeles, lakers, star, lebron, james, named, ...
# 1976    [paolo, rossi, tribute, best, peter, allis, te...
# 1977    [angeles, lakers, star, lebron, james, named, ...
# 1978    [angeles, lakers, star, lebron, james, named, ...
# 1979    [update, player, released, canada’s, national,...
# 1980    [thrilled, lauren, sport, featured, luxury, tr...
# 1981    [europa, league, dundalk, arsenal, lech, pozna...
# 1982    [paolo, rossi, tribute, best, peter, allis, te...
# 1983    [paolo, rossi, tribute, best, peter, allis, te...
# 1984    [paolo, rossi, tribute, best, peter, allis, te...
# 1985    [paolo, rossi, tribute, best, peter, allis, te...
# 1986    [rugby, dementia, plight, expose, chilling, st...
# 1987    [angeles, lakers, star, lebron, james, named, ...
# 1988    [paolo, rossi, tribute, best, peter, allis, te...
# 1989    [update, player, released, canada’s, national,...
# 1990    [paolo, rossi, tribute, best, peter, allis, et...
# 1991    [paolo, rossi, tribute, best, peter, allis, te...
# 1992    [sport, made, imsa, debut, rolex, httpstcoskxu...
# 1993    [angeles, lakers, star, lebron, james, named, ...
# 1994    [olympic, committee, wont, discipline, protest...
# 1995    [update, player, released, canada’s, national,...
# 1996    [angeles, lakers, star, lebron, james, named, ...
# 1997    [dementia, link, lead, call, collision, rugby,...
# 1998    [update, player, released, canada’s, national,...
# 1999    [angeles, lakers, star, lebron, james, named, ...
# Name: Tweet_lemmatized, Length: 2000, dtype: object

# %%
df.Tweet_lemmatized.to_csv('Databases/Tweets_cleaned.csv',index = False)

# %%
new_tweet_df= pd.read_csv('Databases/Tweets_cleaned.csv')
new_tweet_df.head()
# Out:
#                                     Tweet_lemmatized
# 0      ['rt', 'shesooosaddity', 'twitter', '', 'rt']
# 1                                  ['cloudnaii', '']
# 2  ['issahairplug', 'drink', 'water', 'replaced',...
# 3           ['nethatguy', 'taking', 'oomf', 'fleet']
# 4  ['jusjust', 'remember', 'dedicate', 'th', 'twe...

# %%
print('Dataset size:',new_tweet_df.shape)
print('Columns are:',new_tweet_df.columns)
# Out:
# Dataset size: (3218, 1)
# Columns are: Index(['Tweet_lemmatized'], dtype='object')

# %% [markdown]
# ## Vectorisation
# - Les données nettoyées en une seule ligne en passant new_tweet_df dans le CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X=cv.fit_transform(new_tweet_df.Tweet_lemmatized)
print(X)
# Out:
#   (0, 5754)	1
#   (0, 4921)	1
#   (0, 4699)	2
#   (1, 932)	1
#   (2, 3721)	1
#   (2, 1923)	1
#   (2, 4587)	1
#   (2, 5962)	1
#   (2, 1380)	1
#   (2, 2792)	1
#   (3, 1743)	1
#   (3, 4125)	1
#   (3, 5364)	1
#   (3, 3860)	1
#   (4, 5740)	1
#   (4, 5432)	1
#   (4, 1221)	1
#   (4, 4575)	1
#   (4, 3028)	1
#   (5, 5658)	1
#   (5, 181)	1
#   (6, 4635)	1
#   (6, 4410)	1
#   (6, 4267)	1
#   (7, 1744)	1
#   :	:
#   (3213, 285)	1
#   (3213, 5533)	1
#   (3213, 624)	1
#   (3214, 974)	1
#   (3214, 876)	1
#   (3214, 2021)	1
#   (3214, 1997)	1
#   (3214, 148)	1
#   (3214, 6015)	1
#   (3214, 5766)	1
#   (3214, 5991)	1
#   (3215, 3163)	1
#   (3215, 1336)	1
#   (3215, 2123)	1
#   (3215, 1935)	1
#   (3216, 2749)	1
#   (3216, 789)	1
#   (3216, 3557)	1
#   (3217, 1991)	1
#   (3217, 3682)	1
#   (3217, 189)	1
#   (3217, 3955)	1
#   (3217, 5740)	1
#   (3217, 3721)	1
#   (3217, 1923)	2

# %% [markdown]
# ## Classification des tweets
#
# * Cette approche utilise la technique de création d'un ensemble de mots qui peuvent être classés en toute confiance comme  appartenant à une catégorie particulière .
# * On va Utiliser l’algorithme K-Means pour classer les Tweets en 30 classes.

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(3,30):
   
    Kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0,verbose=True)
    Kmeans.fit(X)
    wcss.append(Kmeans.inertia_)
# Out:
# Initialization complete
# Iteration  0, inertia 25318.000
# Iteration  1, inertia 12879.516
# Iteration  2, inertia 12874.904
# Converged at iteration 2: center shift 0.000000e+00 within tolerance 6.594548e-08
# Initialization complete
# Iteration  0, inertia 19594.000
# Iteration  1, inertia 13021.577
# Iteration  2, inertia 13002.118
# Iteration  3, inertia 13002.066
# Converged at iteration 3: center shift 0.000000e+00 within tolerance 6.594548e-08
# Initialization complete
# Iteration  0, inertia 19320.000
# Iteration  1, inertia 12877.345
# Iteration  2, inertia 12840.441
# Iteration  3, inertia 12807.083
# Iteration  4, inertia 12806.411
# Iteration  5, inertia 12806.130
# Iteration  6, inertia 12805.178
# Iteration  7, inertia 12775.935
# Iteration  8, inertia 12715.778
# Iteration  9, inertia 12715.614
# Converged at iteration 9: center shift 0.000000e+00 within tolerance 6.594548e-08
# Initialization complete
# Iteration  0, inertia 16470.000
# Iteration  1, inertia 13121.963
# Iteration  2, inertia 13099.389
# Converged at iteration 2: center shift 0.000000e+00 within tolerance 6.594548e-08
# Initialization complete
# Iteration  0, inertia 19632.000
# Iteration  1, inertia 13071.584
# Iteration  2, inertia 13041.213
# Iteration  3, inertia 13002.899
# Converged at iteration 3: center shift 0.000000e+00 within tolerance 6.594548e-08
# Initialization complete
# Iteration  0, inertia 22754.000
# Iteration  1, inertia 13144.035
# Iteration  2, inertia 13083.051
# Iteration  3, inertia 13077.509
# Iteration  4, inertia 13076.418
# Iteration  5, inertia 13060.540
# Iteration  6, inertia 12985.104
# Iteration  7, inertia 12984.895
# Converged at iteration 7: center shift 0.000000e+00 within tolerance 6.594548e-08
# Initialization complete
# Iteration  0, inertia 
# Converged at iteration 5: center shift 0.000000e+00 within tolerance 6.594548e-08
# Initialization complete
# Iteration  0, inertia 15860.000
# Iteration  1, inertia 12420.406
# Iteration  2, inertia 12407.744
# Iteration  3, inertia 12355.710
# Iteration  4, inertia 12296.555
# Iteration  5, inertia 12285.230
# Converged at iteration 5: center shift 0.000000e+00 within tolerance 6.594548e-08
# Initialization complete
# Iteration  0, inertia 15791.000
# Iteration  1, inertia 12079.000
# Iteration  2, inertia 12067.010
# Iteration  3, inertia 12063.518
# Iteration  4, inertia 12057.470
# Iteration  5, inertia 12053.906
# Converged at iteration 5: center shift 0.000000e+00 within tolerance 6.594548e-08

# %%
import matplotlib.pyplot as plt
plt.plot(range(3,30),wcss)
plt.xlabel('number of clusters')
plt.ylabel('word per cluster')
plt.show()

# %%
true_k=30
Kmeans=KMeans(n_clusters=true_k,init='k-means++',n_init=1)
Kmeans.fit(X)
print("Top terms per cluster:")
order_centroids = Kmeans.cluster_centers_.argsort()[:, ::-1]
terms = cv.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i)
    print("-----------------------")
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind])
    print()
print("\n")
# Out:
# Top terms per cluster:
# Cluster 0:
# -----------------------
#  year
#  day
#  tweet
#  didnt
#  happy
#  got
#  leap
#  start
#  two
#  even
#
# Cluster 1:
# -----------------------
#  follow
#  gratitude
#  dm
#  love
#  share
#  we
#  much
#  mauradonohoe
#  kathrynristic
#  katem
#
# Cluster 2:
# -----------------------
#  tweet
#  one
#  good
#  like
#  rt
#  say
#  back
#  got
#  read
#  best
#
# Cluster 3:
# -----------------------
#  show
#  nyour
#  sjschauer
#  cmon
#  out
#  damnezzy
#  follower
#  like
#  respect
#  hbssgcstan
#
# Cluster 4:
# -----------------------
#  tell
#  better
#  please
#  wont
#  twitter
#  feel
#  aftsyd
#  picking
#  regret
#  tobythefox
#
# Cluster 5:
# -----------------------
#  well
#  actually
#  work
#  back
#  georgesiuver
#  picture
#  night
#  waiting
#  huntermoonshot
#  owusuansahjere
#
# Cluster 6:
# -----------------------
#  yes
#  sign
#  point
#  see
#  definitely
#  tugbabodrumlu
#  leobeletsky
#  waiting
#  hongtopia
#  hagridfcb
#
# Cluster 7:
# -----------------------
#  dm
#  sliding
#  right
#  httpstcogiddzoqv
#  yup
#  briannabeckeru
#  httpstcouvcebeu
#  normanisnack
#  httpstcoqiacpiyyxf
#  tinaaaclavell
#
# Cluster 8:
# -----------------------
#  time
#  first
#  twitter
#  real
#  right
#  thought
#  mutuals
#  long
#  keep
#  like
#
# Cluster 9:
# -----------------------
#  like
#  know
#  one
#  need
#  good
#  love
#  day
#  real
#  rt
#  look
#
# Cluster 10:
# -----------------------
#  never
#  happened
#  esperredittt
#  dm
#  yassss
#  thought
#  httpstcowadjnep
#  asiwajulerry
#  twitter
#  happen
#
# Cluster 11:
# -----------------------
#  twitter
#  start
#  beauty
#  piarayensii
#  skincare
#  skin
#  app
#  haunted
#  have
#  havishaf
#
# Cluster 12:
# -----------------------
#  article
#  it
#  read
#  reading
#  growth
#  we
#  retweet
#  retweeting
#  ll
#  remind
#
# Cluster 13:
# -----------------------
#  dming
#  start
#  babyczk
#  easy
#  funny
#  tweet
#  いつもより出てくるtwitterの誕生日祝い
#  hazy
#  haw
#  hawyeehoran
#
# Cluster 14:
# -----------------------
#  dm
#  follow
#  treat
#  send
#  sweet
#  deets
#  well
#  soon
#  check
#  comin
#
# Cluster 15:
# -----------------------
#  time
#  next
#  tweet
#  watch
#  quote
#  changing
#  nhttpstcowawouger
#  world
#  chrisxdrian
#  liftoff
#
# Cluster 16:
# -----------------------
#  famous
#  twitter
#  garyfromteenmom
#  subway
#  gt
#  hazy
#  have
#  havishaf
#  haw
#  hawyeehoran
#
# Cluster 17:
# -----------------------
#  dog
#  thought
#  another
#  lead
#  one
#  ibdwr
#  いつもより出てくるtwitterの誕生日祝い
#  hazy
#  hawyeehoran
#  haxorusx
#
# Cluster 18:
# -----------------------
#  heart
#  make
#  grow
#  fonder
#  lameaschris
#  period
#  distance
#  tweet
#  いつもより出てくるtwitterの誕生日祝い
#  hawyeehoran
#
# Cluster 19:
# -----------------------
#  back
#  got
#  follower
#  door
#  question
#  snapbackrehab
#  sexy
#  notification
#  seungminavocado
#  ll
#
# Cluster 20:
# -----------------------
#  nasa
#  work
#  send
#  check
#  nasapersevere
#  make
#  often
#  pic
#  hayleysrant
#  havishaf
#
# Cluster 21:
# -----------------------
#  convo
#  without
#  fish
#  tube
#  imagine
#  reference
#  sureokae
#  いつもより出てくるtwitterの誕生日祝い
#  hawyeehoran
#  haxorusx
#
# Cluster 22:
# -----------------------
#  wait
#  tweet
#  like
#  pic
#  find
#  least
#  to
#  see
#  numbercat
#  mom
#
# Cluster 23:
# -----------------------
#  like
#  timeline
#  looking
#  balencihoya
#  callmeayokay
#  literally
#  tzirs
#  septuplets
#  live
#  hbveo
#
# Cluster 24:
# -----------------------
#  june
#  rt
#  day
#  educa
#  celebration
#  company
#  square
#  forevermore
#  making
#  holiday
#
# Cluster 25:
# -----------------------
#  twitter
#  rt
#  know
#  love
#  friend
#  stan
#  first
#  thing
#  tweet
#  want
#
# Cluster 26:
# -----------------------
#  you
#  got
#  android
#  pin
#  nhttpstcongfkbaag
#  re
#  it
#  いつもより出てくるtwitterの誕生日祝い
#  hayleysrant
#  have
#
# Cluster 27:
# -----------------------
#  labor
#  became
#  okay
#  white
#  five
#  year
#  wearing
#  day
#  luulubuu
#  haw
#
# Cluster 28:
# -----------------------
#  day
#  hump
#  nothing
#  say
#  mother
#  horny
#  cfcenw
#  groundhog
#  nap
#  cancel
#
# Cluster 29:
# -----------------------
#  better
#  never
#  make
#  list
#  even
#  right
#  mattryanx
#  late
#  tweet
#  ludwigahgren

# %%
i=0
j=0
while i<28:
    while True: 
        Y=cv.transform([new_tweet_df.Tweet_lemmatized[j]])
        prediction=Kmeans.predict(Y)
        if i == prediction:
            print("Tweet of cluster "+str(prediction)+" : "+df.Tweet_lemmatized[i])
            print ("-----------------------------------------------")
            print("\n")
            j=0
            break
        j+=1
    i+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-259bac10a0a1> in <module>
#       6         prediction=Kmeans.predict(Y)
#       7         if i == prediction:
# ----> 8             print("Tweet of cluster "+str(prediction)+" : "+df.Tweet_lemmatized[i])
#       9             print ("-----------------------------------------------")
#      10             print("\n")
#
# TypeError: can only concatenate str (not "list") to str
